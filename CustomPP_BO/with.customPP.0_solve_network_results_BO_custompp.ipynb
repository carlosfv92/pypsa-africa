# %% [markdown]
# # Plotting PyPSA results (adapted for the First Run of Bolivia - config.yaml file)
#
# ### Adele will check for additional results that can be used

# %%
###### algunas cosas cambian si pongo como comentarios en el import de geoviews y hvplot (liberias conflictivas?)

import logging
import os

import pypsa
import yaml
import pandas as pd
import geopandas as gpd
#import geoviews as gv
#import hvplot.pandas 
import numpy as np
import scipy as sp
import networkx as nx

# plotting stuff
import matplotlib.pyplot as plt

plt.style.use("bmh")
import seaborn as sns  ###
import cartopy.crs as ccrs

sns.set(style="darkgrid")

from scipy.sparse import csgraph
from itertools import product

from shapely.geometry import Point, LineString
import shapely, shapely.prepared, shapely.wkt

logger = logging.getLogger(__name__)

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 70)

import sys

sys.path.append("../")  # to import helpers
from scripts._helpers import sets_path_to_root

sets_path_to_root("pypsa-earth")

max_node_size = 1.0  # maximum size of a node for plotting purposes [used in plots]
# Out:
# This is the repository path:  c:\Users\Lenovo\Desktop\pypsa-earth
# Had to go 1 folder(s) up.

# %%
# utility function for nice plotting


def normalize_node_size(values, max_node_size=max_node_size):
    return values / values.max() * max_node_size

# %% [markdown]
# # Load all networks

# %%
# add_electricity_network = os.getcwd() + '/networks/elec.nc'
# n_add_el = pypsa.Network(add_electricity_network)

# clustered_network = os.getcwd() + '/networks/elec_s_20.nc'
# n_cluster = pypsa.Network(clustered_network)



#Se carga el documento (o la direccion/path del mismo) a una variable (solved_network)

solved_network = os.getcwd() + "/results/networks/elec_s_10_ec_lcopt_Co2L-6H.nc"

#Se cargan los resultados de la optimizacion del problema segun las caracteristicas definidas para el modelo en n_solve con la funcion (operador?) Network de pypsa

n_solve = pypsa.Network(solved_network)
# Out:
# INFO:pypsa.io:Imported network elec_s_10_ec_lcopt_Co2L-6H.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %% [markdown]
# # Solved network

# %%
n = n_solve

# %%
# ".global_constraints" muestra las restricciones consideradas para el modelo (en el config.yaml solo se tomo en cuenta el limite de emisiones) tonCO2/year

n.global_constraints
# Out:
#                  sense    constant            type  investment_period  \
# GlobalConstraint
# CO2Limit            <=  77500000.0  primary_energy                NaN
#
#                  carrier_attribute   mu
# GlobalConstraint
# CO2Limit             co2_emissions  0.0

# %%
#Calculo del precio promedio de energia promedio en la red (costo total de operacion)= ".objective" /  (sumatoria de las cargas variables en el tiempo)
# EURO/MWh

##### check why the value does not appear 
#   - It seems that while the model run before, due to restrictions on simulation, proper solving wasn't possible (by increasing tolerances of the solver the model gets actual results)


n.objective
# Out:
# 3903264058.282946

# %% [markdown]
# ### Spatial temporal resolution

# %%
#Resultado grafico de la red electrica ideal (lineas verdes representan expansiones de la red)

#####beacuase all buses are not connected it might be that the problem is not fully solved 
# - Lines used in the model don't consider newer power lines (data bases were not apdated)
# - This is proved by comparing raw lines (all available lines in OSM) and clean lines (processed lines to be used in the model)
# - A linker is required to include new/additional data into the "all_clean_lines.geojson"


n.plot()
# Out:
# (<matplotlib.collections.PatchCollection at 0x2aff90df1c0>,
#  <matplotlib.collections.LineCollection at 0x2aff91ae560>,
#  <matplotlib.collections.LineCollection at 0x2aff91ae4d0>)

# %%
#Se muestra el tamaño de la resolucion temporal del modelo - timesteps 
# - Currently the system is working with a toy version of Bolivia to allow faster solving times (6h time aggregation and a little over 5 months acoording the rules in the config.yaml file) 
# - A more complete model should be run eventually with different conditions (higher time resolution) or methods like tsam (https://tsam.readthedocs.io/en/latest/mathematicalBackgroundDoc.html)
#  

len(n.snapshots)
# Out:
# 624

# %% [markdown]
# ### Overview components

# %%
#Imprimir la lista de componentes considerados en el dataframe creado

for c in n.iterate_components(list(n.components.keys())[2:]):
    print("Component '{}' has {} entries".format(c.name, len(c.df)))
# Out:
# Component 'Bus' has 30 entries
# Component 'Carrier' has 16 entries
# Component 'GlobalConstraint' has 1 entries
# Component 'Line' has 8 entries
# Component 'LineType' has 34 entries
# Component 'TransformerType' has 14 entries
# Component 'Link' has 40 entries
# Component 'Load' has 10 entries
# Component 'Generator' has 33 entries
# Component 'StorageUnit' has 5 entries
# Component 'Store' has 20 entries

# %% [markdown]
# ### Energy balance

# %%
# ".stores_t" hace referencia a la energia que se puede almacenar en un bus (se usa para definir otras tecnologias como storage)
# - https://pypsa.readthedocs.io/en/latest/components.html#store

n.stores_t.p.sum()
# Out:
# Store
# BO 0 H2         0.0
# BO 1 H2         0.0
# BO 2 H2         0.0
# BO 3 H2         0.0
# BO 4 H2         0.0
# BO 5 H2         0.0
# BO 6 H2         0.0
# BO 7 H2         0.0
# BO 8 H2         0.0
# BO 9 H2         0.0
# BO 0 battery    0.0
# BO 1 battery    0.0
# BO 2 battery    0.0
# BO 3 battery    0.0
# BO 4 battery    0.0
# BO 5 battery    0.0
# BO 6 battery    0.0
# BO 7 battery    0.0
# BO 8 battery    0.0
# BO 9 battery    0.0
# dtype: float64

# %%
# se imprimen todos los generadores considerados en el modelo

##### check if loadshedding is being used in the config.yaml file, at the solving section 
# - load shedding is represented in the model by the inclution on additional "load" generation/generators 


n.generators

print(type(n.generators))
print(n.generators.columns)
n.generators
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['p_nom_max', 'weight', 'p_nom', 'capital_cost', 'efficiency',
#        'p_nom_min', 'marginal_cost', 'bus', 'carrier', 'control', 'p_nom_opt',
#        'sign', 'build_year', 'min_up_time', 'min_down_time', 'up_time_before',
#        'down_time_before', 'type', 'p_nom_extendable', 'p_min_pu', 'p_max_pu',
#        'p_set', 'q_set', 'lifetime', 'committable', 'start_up_cost',
#        'shut_down_cost', 'ramp_limit_up', 'ramp_limit_down',
#        'ramp_limit_start_up', 'ramp_limit_shut_down'],
#       dtype='object')
#                  p_nom_max         weight         p_nom   capital_cost  \
# Generator
# BO 0 onwind   1.288879e+05    1351.910844  2.186493e-01  109295.569252
# BO 0 solar    1.612263e+05   30267.135767  1.090383e+01   50855.958267
# BO 1 onwind   3.008036e+04     136.742382  0.000000e+00  109295.569252
# BO 1 solar    3.633636e+04    5809.740368  2.138826e+00   50855.958267
# BO 2 biomass           inf       0.000000  7.229000e+01  278015.359506
# BO 2 onwind   5.872036e+05   59888.246048  1.218925e+01  109295.569252
# BO 2 solar    2.221573e+05   30992.064349  1.126932e+01   50855.958267
# BO 3 onwind   6.009534e+05   26703.715966  6.511923e+00  109295.569252
# BO 3 solar    6.995203e+05  135071.632048  5.009812e+01   50855.958267
# BO 4 biomass           inf       0.000000  4.940000e+00  278015.359506
# BO 4 oil               inf       0.000000  1.174000e+01   38234.561404
# BO 4 onwind   7.178415e+05   28760.831046  5.604937e+00  109295.569252
# BO 4 solar    3.910029e+05   52379.941288  1.938137e+01   50855.958267
# BO 5 onwind   1.982455e+05    5754.541306  1.040536e+00  109295.569252
# BO 5 solar    3.039954e+05   61268.474745  2.266456e+01   50855.958267
# BO 6 onwind   1.721649e+04      31.103250  0.000000e+00  109295.569252
# BO 6 solar    2.285400e+04    3803.984631  1.020185e+00   50855.958267
# BO 7 onwind   6.003360e+04    1814.012430  3.994141e-01  109295.569252
# BO 7 solar    2.570774e+04    3526.544511  1.303722e+00   50855.958267
# BO 8 onwind   3.169000e+04       6.538648  0.000000e+00  109295.569252
# BO 8 solar    7.799832e+02      94.299926  0.000000e+00   50855.958267
# BO 9 onwind   3.894440e+03      38.728584  0.000000e+00  109295.569252
# BO 9 solar    6.051754e+03    1104.440890  4.097973e-01   50855.958267
# BO 0 load              inf            NaN  1.000000e+09       0.000000
# BO 1 load              inf            NaN  1.000000e+09       0.000000
# BO 2 load              inf            NaN  1.000000e+09       0.000000
# BO 3 load              inf            NaN  1.000000e+09       0.000000
# BO 4 load              inf            NaN  1.000000e+09       0.000000
# BO 5 load              inf            NaN  1.000000e+09       0.000000
# BO 6 load              inf            NaN  1.000000e+09       0.000000
# BO 7 load              inf            NaN  1.000000e+09       0.000000
# BO 8 load              inf            NaN  1.000000e+09       0.000000
# BO 9 load              inf            NaN  1.000000e+09       0.000000
#
#               efficiency  p_nom_min  marginal_cost   bus  carrier control  \
# Generator
# BO 0 onwind        1.000   0.218649       0.025123  BO 0   onwind   Slack
# BO 0 solar         1.000  10.903831       0.019784  BO 0    solar
# BO 1 onwind        1.000   0.000000       0.024297  BO 1   onwind
# BO 1 solar         1.000   2.138826       0.020525  BO 1    solar
# BO 2 biomass       0.468  72.290000      14.967664  BO 2  biomass
# BO 2 onwind        1.000  12.189249       0.025822  BO 2   onwind
# BO 2 solar         1.000  11.269319       0.019443  BO 2    solar
# BO 3 onwind        1.000   6.511923       0.024884  BO 3   onwind
# BO 3 solar         1.000  50.098120       0.020460  BO 3    solar
# BO 4 biomass       0.468   4.940000      14.966646  BO 4  biomass   Slack
# BO 4 oil           0.393  11.740000     130.237119  BO 4      oil
# BO 4 onwind        1.000   5.604937       0.024534  BO 4   onwind
# BO 4 solar         1.000  19.381369       0.020593  BO 4    solar
# BO 5 onwind        1.000   1.040536       0.024099  BO 5   onwind
# BO 5 solar         1.000  22.664558       0.019220  BO 5    solar
# BO 6 onwind        1.000   0.000000       0.025579  BO 6   onwind
# BO 6 solar         1.000   1.020185       0.020793  BO 6    solar
# BO 7 onwind        1.000   0.399414       0.024984  BO 7   onwind
# BO 7 solar         1.000   1.303722       0.019071  BO 7    solar
# BO 8 onwind        1.000   0.000000       0.024167  BO 8   onwind   Slack
# BO 8 solar         1.000   0.000000       0.019337  BO 8    solar
# BO 9 onwind        1.000   0.000000       0.024649  BO 9   onwind   Slack
# BO 9 solar         1.000   0.409797       0.019644  BO 9    solar
# BO 0 load          1.000   0.000000       1.010164  BO 0     load      PQ
# BO 1 load          1.000   0.000000       1.009584  BO 1     load      PQ
# BO 2 load          1.000   0.000000       1.009983  BO 2     load      PQ
# BO 3 load          1.000   0.000000       1.009939  BO 3     load      PQ
# BO 4 load          1.000   0.000000       1.009948  BO 4     load      PQ
# BO 5 load          1.000   0.000000       1.009576  BO 5     load      PQ
# BO 6 load          1.000   0.000000       1.010778  BO 6     load      PQ
# BO 7 load          1.000   0.000000       1.010815  BO 7     load      PQ
# BO 8 load          1.000   0.000000       1.010704  BO 8     load      PQ
# BO 9 load          1.000   0.000000       1.010982  BO 9     load      PQ
#
#                  p_nom_opt   sign  build_year  min_up_time  min_down_time  \
# Generator
# BO 0 onwind   2.186493e-01  1.000           0            0              0
# BO 0 solar    1.090383e+01  1.000           0            0              0
# BO 1 onwind   0.000000e+00  1.000           0            0              0
# BO 1 solar    2.138826e+00  1.000           0            0              0
# BO 2 biomass  7.229000e+01  1.000           0            0              0
# BO 2 onwind   1.218925e+01  1.000           0            0              0
# BO 2 solar    1.126932e+01  1.000           0            0              0
# BO 3 onwind   6.511923e+00  1.000           0            0              0
# BO 3 solar    5.009812e+01  1.000           0            0              0
# BO 4 biomass  4.940000e+00  1.000           0            0              0
# BO 4 oil      1.174000e+01  1.000           0            0              0
# BO 4 onwind   5.604937e+00  1.000           0            0              0
# BO 4 solar    1.938137e+01  1.000           0            0              0
# BO 5 onwind   1.040536e+00  1.000           0            0              0
# BO 5 solar    2.266456e+01  1.000           0            0              0
# BO 6 onwind   0.000000e+00  1.000           0            0              0
# BO 6 solar    1.020185e+00  1.000           0            0              0
# BO 7 onwind   3.994141e-01  1.000           0            0              0
# BO 7 solar    1.303722e+00  1.000           0            0              0
# BO 8 onwind   0.000000e+00  1.000           0            0              0
# BO 8 solar    0.000000e+00  1.000           0            0              0
# BO 9 onwind   0.000000e+00  1.000           0            0              0
# BO 9 solar    4.097973e-01  1.000           0            0              0
# BO 0 load     1.000000e+09  0.001           0            0              0
# BO 1 load     1.000000e+09  0.001           0            0              0
# BO 2 load     1.000000e+09  0.001           0            0              0
# BO 3 load     1.000000e+09  0.001           0            0              0
# BO 4 load     1.000000e+09  0.001           0            0              0
# BO 5 load     1.000000e+09  0.001           0            0              0
# BO 6 load     1.000000e+09  0.001           0            0              0
# BO 7 load     1.000000e+09  0.001           0            0              0
# BO 8 load     1.000000e+09  0.001           0            0              0
# BO 9 load     1.000000e+09  0.001           0            0              0
#
#               up_time_before  down_time_before type  p_nom_extendable  \
# Generator
# BO 0 onwind                1                 0                  False
# BO 0 solar                 1                 0                  False
# BO 1 onwind                1                 0                  False
# BO 1 solar                 1                 0                  False
# BO 2 biomass               1                 0                  False
# BO 2 onwind                1                 0                  False
# BO 2 solar                 1                 0                  False
# BO 3 onwind                1                 0                  False
# BO 3 solar                 1                 0                  False
# BO 4 biomass               1                 0                  False
# BO 4 oil                   1                 0                  False
# BO 4 onwind                1                 0                  False
# BO 4 solar                 1                 0                  False
# BO 5 onwind                1                 0                  False
# BO 5 solar                 1                 0                  False
# BO 6 onwind                1                 0                  False
# BO 6 solar                 1                 0                  False
# BO 7 onwind                1                 0                  False
# BO 7 solar                 1                 0                  False
# BO 8 onwind                1                 0                  False
# BO 8 solar                 1                 0                  False
# BO 9 onwind                1                 0                  False
# BO 9 solar                 1                 0                  False
# BO 0 load                  1                 0                  False
# BO 1 load                  1                 0                  False
# BO 2 load                  1                 0                  False
# BO 3 load                  1                 0                  False
# BO 4 load                  1                 0                  False
# BO 5 load                  1                 0                  False
# BO 6 load                  1                 0                  False
# BO 7 load                  1                 0                  False
# BO 8 load                  1                 0                  False
# BO 9 load                  1                 0                  False
#
#               p_min_pu  p_max_pu  p_set  q_set  lifetime  committable  \
# Generator
# BO 0 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 0 solar         0.0       1.0    0.0    0.0       inf        False
# BO 1 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 1 solar         0.0       1.0    0.0    0.0       inf        False
# BO 2 biomass       0.0       1.0    0.0    0.0       inf        False
# BO 2 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 2 solar         0.0       1.0    0.0    0.0       inf        False
# BO 3 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 3 solar         0.0       1.0    0.0    0.0       inf        False
# BO 4 biomass       0.0       1.0    0.0    0.0       inf        False
# BO 4 oil           0.0       1.0    0.0    0.0       inf        False
# BO 4 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 4 solar         0.0       1.0    0.0    0.0       inf        False
# BO 5 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 5 solar         0.0       1.0    0.0    0.0       inf        False
# BO 6 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 6 solar         0.0       1.0    0.0    0.0       inf        False
# BO 7 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 7 solar         0.0       1.0    0.0    0.0       inf        False
# BO 8 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 8 solar         0.0       1.0    0.0    0.0       inf        False
# BO 9 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 9 solar         0.0       1.0    0.0    0.0       inf        False
# BO 0 load          0.0       1.0    0.0    0.0       inf        False
# BO 1 load          0.0       1.0    0.0    0.0       inf        False
# BO 2 load          0.0       1.0    0.0    0.0       inf        False
# BO 3 load          0.0       1.0    0.0    0.0       inf        False
# BO 4 load          0.0       1.0    0.0    0.0       inf        False
# BO 5 load          0.0       1.0    0.0    0.0       inf        False
# BO 6 load          0.0       1.0    0.0    0.0       inf        False
# BO 7 load          0.0       1.0    0.0    0.0       inf        False
# BO 8 load          0.0       1.0    0.0    0.0       inf        False
# BO 9 load          0.0       1.0    0.0    0.0       inf        False
#
#               start_up_cost  shut_down_cost  ramp_limit_up  ramp_limit_down  \
# Generator
# BO 0 onwind             0.0             0.0            NaN              NaN
# BO 0 solar              0.0             0.0            NaN              NaN
# BO 1 onwind             0.0             0.0            NaN              NaN
# BO 1 solar              0.0             0.0            NaN              NaN
# BO 2 biomass            0.0             0.0            NaN              NaN
# BO 2 onwind             0.0             0.0            NaN              NaN
# BO 2 solar              0.0             0.0            NaN              NaN
# BO 3 onwind             0.0             0.0            NaN              NaN
# BO 3 solar              0.0             0.0            NaN              NaN
# BO 4 biomass            0.0             0.0            NaN              NaN
# BO 4 oil                0.0             0.0            NaN              NaN
# BO 4 onwind             0.0             0.0            NaN              NaN
# BO 4 solar              0.0             0.0            NaN              NaN
# BO 5 onwind             0.0             0.0            NaN              NaN
# BO 5 solar              0.0             0.0            NaN              NaN
# BO 6 onwind             0.0             0.0            NaN              NaN
# BO 6 solar              0.0             0.0            NaN              NaN
# BO 7 onwind             0.0             0.0            NaN              NaN
# BO 7 solar              0.0             0.0            NaN              NaN
# BO 8 onwind             0.0             0.0            NaN              NaN
# BO 8 solar              0.0             0.0            NaN              NaN
# BO 9 onwind             0.0             0.0            NaN              NaN
# BO 9 solar              0.0             0.0            NaN              NaN
# BO 0 load               0.0             0.0            NaN              NaN
# BO 1 load               0.0             0.0            NaN              NaN
# BO 2 load               0.0             0.0            NaN              NaN
# BO 3 load               0.0             0.0            NaN              NaN
# BO 4 load               0.0             0.0            NaN              NaN
# BO 5 load               0.0             0.0            NaN              NaN
# BO 6 load               0.0             0.0            NaN              NaN
# BO 7 load               0.0             0.0            NaN              NaN
# BO 8 load               0.0             0.0            NaN              NaN
# BO 9 load               0.0             0.0            NaN              NaN
#
#               ramp_limit_start_up  ramp_limit_shut_down
# Generator
# BO 0 onwind                   1.0                   1.0
# BO 0 solar                    1.0                   1.0
# BO 1 onwind                   1.0                   1.0
# BO 1 solar                    1.0                   1.0
# BO 2 biomass                  1.0                   1.0
# BO 2 onwind                   1.0                   1.0
# BO 2 solar                    1.0                   1.0
# BO 3 onwind                   1.0                   1.0
# BO 3 solar                    1.0                   1.0
# BO 4 biomass                  1.0                   1.0
# BO 4 oil                      1.0                   1.0
# BO 4 onwind                   1.0                   1.0
# BO 4 solar                    1.0                   1.0
# BO 5 onwind                   1.0                   1.0
# BO 5 solar                    1.0                   1.0
# BO 6 onwind                   1.0                   1.0
# BO 6 solar                    1.0                   1.0
# BO 7 onwind                   1.0                   1.0
# BO 7 solar                    1.0                   1.0
# BO 8 onwind                   1.0                   1.0
# BO 8 solar                    1.0                   1.0
# BO 9 onwind                   1.0                   1.0
# BO 9 solar                    1.0                   1.0
# BO 0 load                     1.0                   1.0
# BO 1 load                     1.0                   1.0
# BO 2 load                     1.0                   1.0
# BO 3 load                     1.0                   1.0
# BO 4 load                     1.0                   1.0
# BO 5 load                     1.0                   1.0
# BO 6 load                     1.0                   1.0
# BO 7 load                     1.0                   1.0
# BO 8 load                     1.0                   1.0
# BO 9 load                     1.0                   1.0

# %%
#Imprimir solo los generadores de Bolivia

########(this is only necessary if several countries are studied at the same time

idx = ['BO' in x for x in n.generators.index]
n.generators.loc[idx,:]
# Out:
#                  p_nom_max         weight         p_nom   capital_cost  \
# Generator
# BO 0 onwind   1.288879e+05    1351.910844  2.186493e-01  109295.569252
# BO 0 solar    1.612263e+05   30267.135767  1.090383e+01   50855.958267
# BO 1 onwind   3.008036e+04     136.742382  0.000000e+00  109295.569252
# BO 1 solar    3.633636e+04    5809.740368  2.138826e+00   50855.958267
# BO 2 biomass           inf       0.000000  7.229000e+01  278015.359506
# BO 2 onwind   5.872036e+05   59888.246048  1.218925e+01  109295.569252
# BO 2 solar    2.221573e+05   30992.064349  1.126932e+01   50855.958267
# BO 3 onwind   6.009534e+05   26703.715966  6.511923e+00  109295.569252
# BO 3 solar    6.995203e+05  135071.632048  5.009812e+01   50855.958267
# BO 4 biomass           inf       0.000000  4.940000e+00  278015.359506
# BO 4 oil               inf       0.000000  1.174000e+01   38234.561404
# BO 4 onwind   7.178415e+05   28760.831046  5.604937e+00  109295.569252
# BO 4 solar    3.910029e+05   52379.941288  1.938137e+01   50855.958267
# BO 5 onwind   1.982455e+05    5754.541306  1.040536e+00  109295.569252
# BO 5 solar    3.039954e+05   61268.474745  2.266456e+01   50855.958267
# BO 6 onwind   1.721649e+04      31.103250  0.000000e+00  109295.569252
# BO 6 solar    2.285400e+04    3803.984631  1.020185e+00   50855.958267
# BO 7 onwind   6.003360e+04    1814.012430  3.994141e-01  109295.569252
# BO 7 solar    2.570774e+04    3526.544511  1.303722e+00   50855.958267
# BO 8 onwind   3.169000e+04       6.538648  0.000000e+00  109295.569252
# BO 8 solar    7.799832e+02      94.299926  0.000000e+00   50855.958267
# BO 9 onwind   3.894440e+03      38.728584  0.000000e+00  109295.569252
# BO 9 solar    6.051754e+03    1104.440890  4.097973e-01   50855.958267
# BO 0 load              inf            NaN  1.000000e+09       0.000000
# BO 1 load              inf            NaN  1.000000e+09       0.000000
# BO 2 load              inf            NaN  1.000000e+09       0.000000
# BO 3 load              inf            NaN  1.000000e+09       0.000000
# BO 4 load              inf            NaN  1.000000e+09       0.000000
# BO 5 load              inf            NaN  1.000000e+09       0.000000
# BO 6 load              inf            NaN  1.000000e+09       0.000000
# BO 7 load              inf            NaN  1.000000e+09       0.000000
# BO 8 load              inf            NaN  1.000000e+09       0.000000
# BO 9 load              inf            NaN  1.000000e+09       0.000000
#
#               efficiency  p_nom_min  marginal_cost   bus  carrier control  \
# Generator
# BO 0 onwind        1.000   0.218649       0.025123  BO 0   onwind   Slack
# BO 0 solar         1.000  10.903831       0.019784  BO 0    solar
# BO 1 onwind        1.000   0.000000       0.024297  BO 1   onwind
# BO 1 solar         1.000   2.138826       0.020525  BO 1    solar
# BO 2 biomass       0.468  72.290000      14.967664  BO 2  biomass
# BO 2 onwind        1.000  12.189249       0.025822  BO 2   onwind
# BO 2 solar         1.000  11.269319       0.019443  BO 2    solar
# BO 3 onwind        1.000   6.511923       0.024884  BO 3   onwind
# BO 3 solar         1.000  50.098120       0.020460  BO 3    solar
# BO 4 biomass       0.468   4.940000      14.966646  BO 4  biomass   Slack
# BO 4 oil           0.393  11.740000     130.237119  BO 4      oil
# BO 4 onwind        1.000   5.604937       0.024534  BO 4   onwind
# BO 4 solar         1.000  19.381369       0.020593  BO 4    solar
# BO 5 onwind        1.000   1.040536       0.024099  BO 5   onwind
# BO 5 solar         1.000  22.664558       0.019220  BO 5    solar
# BO 6 onwind        1.000   0.000000       0.025579  BO 6   onwind
# BO 6 solar         1.000   1.020185       0.020793  BO 6    solar
# BO 7 onwind        1.000   0.399414       0.024984  BO 7   onwind
# BO 7 solar         1.000   1.303722       0.019071  BO 7    solar
# BO 8 onwind        1.000   0.000000       0.024167  BO 8   onwind   Slack
# BO 8 solar         1.000   0.000000       0.019337  BO 8    solar
# BO 9 onwind        1.000   0.000000       0.024649  BO 9   onwind   Slack
# BO 9 solar         1.000   0.409797       0.019644  BO 9    solar
# BO 0 load          1.000   0.000000       1.010164  BO 0     load      PQ
# BO 1 load          1.000   0.000000       1.009584  BO 1     load      PQ
# BO 2 load          1.000   0.000000       1.009983  BO 2     load      PQ
# BO 3 load          1.000   0.000000       1.009939  BO 3     load      PQ
# BO 4 load          1.000   0.000000       1.009948  BO 4     load      PQ
# BO 5 load          1.000   0.000000       1.009576  BO 5     load      PQ
# BO 6 load          1.000   0.000000       1.010778  BO 6     load      PQ
# BO 7 load          1.000   0.000000       1.010815  BO 7     load      PQ
# BO 8 load          1.000   0.000000       1.010704  BO 8     load      PQ
# BO 9 load          1.000   0.000000       1.010982  BO 9     load      PQ
#
#                  p_nom_opt   sign  build_year  min_up_time  min_down_time  \
# Generator
# BO 0 onwind   2.186493e-01  1.000           0            0              0
# BO 0 solar    1.090383e+01  1.000           0            0              0
# BO 1 onwind   0.000000e+00  1.000           0            0              0
# BO 1 solar    2.138826e+00  1.000           0            0              0
# BO 2 biomass  7.229000e+01  1.000           0            0              0
# BO 2 onwind   1.218925e+01  1.000           0            0              0
# BO 2 solar    1.126932e+01  1.000           0            0              0
# BO 3 onwind   6.511923e+00  1.000           0            0              0
# BO 3 solar    5.009812e+01  1.000           0            0              0
# BO 4 biomass  4.940000e+00  1.000           0            0              0
# BO 4 oil      1.174000e+01  1.000           0            0              0
# BO 4 onwind   5.604937e+00  1.000           0            0              0
# BO 4 solar    1.938137e+01  1.000           0            0              0
# BO 5 onwind   1.040536e+00  1.000           0            0              0
# BO 5 solar    2.266456e+01  1.000           0            0              0
# BO 6 onwind   0.000000e+00  1.000           0            0              0
# BO 6 solar    1.020185e+00  1.000           0            0              0
# BO 7 onwind   3.994141e-01  1.000           0            0              0
# BO 7 solar    1.303722e+00  1.000           0            0              0
# BO 8 onwind   0.000000e+00  1.000           0            0              0
# BO 8 solar    0.000000e+00  1.000           0            0              0
# BO 9 onwind   0.000000e+00  1.000           0            0              0
# BO 9 solar    4.097973e-01  1.000           0            0              0
# BO 0 load     1.000000e+09  0.001           0            0              0
# BO 1 load     1.000000e+09  0.001           0            0              0
# BO 2 load     1.000000e+09  0.001           0            0              0
# BO 3 load     1.000000e+09  0.001           0            0              0
# BO 4 load     1.000000e+09  0.001           0            0              0
# BO 5 load     1.000000e+09  0.001           0            0              0
# BO 6 load     1.000000e+09  0.001           0            0              0
# BO 7 load     1.000000e+09  0.001           0            0              0
# BO 8 load     1.000000e+09  0.001           0            0              0
# BO 9 load     1.000000e+09  0.001           0            0              0
#
#               up_time_before  down_time_before type  p_nom_extendable  \
# Generator
# BO 0 onwind                1                 0                  False
# BO 0 solar                 1                 0                  False
# BO 1 onwind                1                 0                  False
# BO 1 solar                 1                 0                  False
# BO 2 biomass               1                 0                  False
# BO 2 onwind                1                 0                  False
# BO 2 solar                 1                 0                  False
# BO 3 onwind                1                 0                  False
# BO 3 solar                 1                 0                  False
# BO 4 biomass               1                 0                  False
# BO 4 oil                   1                 0                  False
# BO 4 onwind                1                 0                  False
# BO 4 solar                 1                 0                  False
# BO 5 onwind                1                 0                  False
# BO 5 solar                 1                 0                  False
# BO 6 onwind                1                 0                  False
# BO 6 solar                 1                 0                  False
# BO 7 onwind                1                 0                  False
# BO 7 solar                 1                 0                  False
# BO 8 onwind                1                 0                  False
# BO 8 solar                 1                 0                  False
# BO 9 onwind                1                 0                  False
# BO 9 solar                 1                 0                  False
# BO 0 load                  1                 0                  False
# BO 1 load                  1                 0                  False
# BO 2 load                  1                 0                  False
# BO 3 load                  1                 0                  False
# BO 4 load                  1                 0                  False
# BO 5 load                  1                 0                  False
# BO 6 load                  1                 0                  False
# BO 7 load                  1                 0                  False
# BO 8 load                  1                 0                  False
# BO 9 load                  1                 0                  False
#
#               p_min_pu  p_max_pu  p_set  q_set  lifetime  committable  \
# Generator
# BO 0 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 0 solar         0.0       1.0    0.0    0.0       inf        False
# BO 1 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 1 solar         0.0       1.0    0.0    0.0       inf        False
# BO 2 biomass       0.0       1.0    0.0    0.0       inf        False
# BO 2 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 2 solar         0.0       1.0    0.0    0.0       inf        False
# BO 3 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 3 solar         0.0       1.0    0.0    0.0       inf        False
# BO 4 biomass       0.0       1.0    0.0    0.0       inf        False
# BO 4 oil           0.0       1.0    0.0    0.0       inf        False
# BO 4 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 4 solar         0.0       1.0    0.0    0.0       inf        False
# BO 5 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 5 solar         0.0       1.0    0.0    0.0       inf        False
# BO 6 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 6 solar         0.0       1.0    0.0    0.0       inf        False
# BO 7 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 7 solar         0.0       1.0    0.0    0.0       inf        False
# BO 8 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 8 solar         0.0       1.0    0.0    0.0       inf        False
# BO 9 onwind        0.0       1.0    0.0    0.0       inf        False
# BO 9 solar         0.0       1.0    0.0    0.0       inf        False
# BO 0 load          0.0       1.0    0.0    0.0       inf        False
# BO 1 load          0.0       1.0    0.0    0.0       inf        False
# BO 2 load          0.0       1.0    0.0    0.0       inf        False
# BO 3 load          0.0       1.0    0.0    0.0       inf        False
# BO 4 load          0.0       1.0    0.0    0.0       inf        False
# BO 5 load          0.0       1.0    0.0    0.0       inf        False
# BO 6 load          0.0       1.0    0.0    0.0       inf        False
# BO 7 load          0.0       1.0    0.0    0.0       inf        False
# BO 8 load          0.0       1.0    0.0    0.0       inf        False
# BO 9 load          0.0       1.0    0.0    0.0       inf        False
#
#               start_up_cost  shut_down_cost  ramp_limit_up  ramp_limit_down  \
# Generator
# BO 0 onwind             0.0             0.0            NaN              NaN
# BO 0 solar              0.0             0.0            NaN              NaN
# BO 1 onwind             0.0             0.0            NaN              NaN
# BO 1 solar              0.0             0.0            NaN              NaN
# BO 2 biomass            0.0             0.0            NaN              NaN
# BO 2 onwind             0.0             0.0            NaN              NaN
# BO 2 solar              0.0             0.0            NaN              NaN
# BO 3 onwind             0.0             0.0            NaN              NaN
# BO 3 solar              0.0             0.0            NaN              NaN
# BO 4 biomass            0.0             0.0            NaN              NaN
# BO 4 oil                0.0             0.0            NaN              NaN
# BO 4 onwind             0.0             0.0            NaN              NaN
# BO 4 solar              0.0             0.0            NaN              NaN
# BO 5 onwind             0.0             0.0            NaN              NaN
# BO 5 solar              0.0             0.0            NaN              NaN
# BO 6 onwind             0.0             0.0            NaN              NaN
# BO 6 solar              0.0             0.0            NaN              NaN
# BO 7 onwind             0.0             0.0            NaN              NaN
# BO 7 solar              0.0             0.0            NaN              NaN
# BO 8 onwind             0.0             0.0            NaN              NaN
# BO 8 solar              0.0             0.0            NaN              NaN
# BO 9 onwind             0.0             0.0            NaN              NaN
# BO 9 solar              0.0             0.0            NaN              NaN
# BO 0 load               0.0             0.0            NaN              NaN
# BO 1 load               0.0             0.0            NaN              NaN
# BO 2 load               0.0             0.0            NaN              NaN
# BO 3 load               0.0             0.0            NaN              NaN
# BO 4 load               0.0             0.0            NaN              NaN
# BO 5 load               0.0             0.0            NaN              NaN
# BO 6 load               0.0             0.0            NaN              NaN
# BO 7 load               0.0             0.0            NaN              NaN
# BO 8 load               0.0             0.0            NaN              NaN
# BO 9 load               0.0             0.0            NaN              NaN
#
#               ramp_limit_start_up  ramp_limit_shut_down
# Generator
# BO 0 onwind                   1.0                   1.0
# BO 0 solar                    1.0                   1.0
# BO 1 onwind                   1.0                   1.0
# BO 1 solar                    1.0                   1.0
# BO 2 biomass                  1.0                   1.0
# BO 2 onwind                   1.0                   1.0
# BO 2 solar                    1.0                   1.0
# BO 3 onwind                   1.0                   1.0
# BO 3 solar                    1.0                   1.0
# BO 4 biomass                  1.0                   1.0
# BO 4 oil                      1.0                   1.0
# BO 4 onwind                   1.0                   1.0
# BO 4 solar                    1.0                   1.0
# BO 5 onwind                   1.0                   1.0
# BO 5 solar                    1.0                   1.0
# BO 6 onwind                   1.0                   1.0
# BO 6 solar                    1.0                   1.0
# BO 7 onwind                   1.0                   1.0
# BO 7 solar                    1.0                   1.0
# BO 8 onwind                   1.0                   1.0
# BO 8 solar                    1.0                   1.0
# BO 9 onwind                   1.0                   1.0
# BO 9 solar                    1.0                   1.0
# BO 0 load                     1.0                   1.0
# BO 1 load                     1.0                   1.0
# BO 2 load                     1.0                   1.0
# BO 3 load                     1.0                   1.0
# BO 4 load                     1.0                   1.0
# BO 5 load                     1.0                   1.0
# BO 6 load                     1.0                   1.0
# BO 7 load                     1.0                   1.0
# BO 8 load                     1.0                   1.0
# BO 9 load                     1.0                   1.0

# %%
#Imprimir la suma de potencias nominales (2013) de los generadores de Bolivia

####### Data was not yet updated and therefore a big difference between real capacities in 2020 (largely oversized) and optimized installed capacities (relatively low changes)
# - To change this, additional plants have to be added to better represent the system

idx = ['BO' in x for x in n.generators.index]
n.generators.loc[idx,:].p_nom.sum()
# Out:
# 10000000234.124435

# %%
# Difference between total load and generation
# losses = n.stores_t

n.generators_t.p.sum().sum() - n.loads_t.p.sum().sum()  # - substract storage losses
# Out:
# 274369749.34310454

# %% [markdown]
# ### Total installed generator capacity

# %%
gen_cap = n.generators.groupby(["carrier"]).sum()
gen_cap
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1472\2958603594.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gen_cap = n.generators.groupby(["carrier"]).sum()
#             p_nom_max         weight         p_nom  capital_cost  efficiency  \
# carrier
# biomass           NaN       0.000000  7.723000e+01  5.560307e+05       0.936
# load              NaN       0.000000  1.000000e+10  0.000000e+00      10.000
# oil               inf       0.000000  1.174000e+01  3.823456e+04       0.393
# onwind   2.376047e+06  124486.370505  2.596471e+01  1.092956e+06      10.000
# solar    1.869632e+06  324318.258522  1.191897e+02  5.085596e+05      10.000
#
#           p_nom_min  marginal_cost     p_nom_opt   sign  build_year  \
# carrier
# biomass   77.230000      29.934310  7.723000e+01   2.00           0
# load       0.000000      10.102473  1.000000e+10   0.01           0
# oil       11.740000     130.237119  1.174000e+01   1.00           0
# onwind    25.964709       0.248138  2.596471e+01  10.00           0
# solar    119.189726       0.198870  1.191897e+02  10.00           0
#
#          min_up_time  min_down_time  up_time_before  down_time_before  \
# carrier
# biomass            0              0               2                 0
# load               0              0              10                 0
# oil                0              0               1                 0
# onwind             0              0              10                 0
# solar              0              0              10                 0
#
#          p_nom_extendable  p_min_pu  p_max_pu  p_set  q_set  lifetime  \
# carrier
# biomass                 0       0.0       2.0    0.0    0.0       NaN
# load                    0       0.0      10.0    0.0    0.0       NaN
# oil                     0       0.0       1.0    0.0    0.0       inf
# onwind                  0       0.0      10.0    0.0    0.0       NaN
# solar                   0       0.0      10.0    0.0    0.0       NaN
#
#          committable  start_up_cost  shut_down_cost  ramp_limit_up  \
# carrier
# biomass            0            0.0             0.0            0.0
# load               0            0.0             0.0            0.0
# oil                0            0.0             0.0            0.0
# onwind             0            0.0             0.0            0.0
# solar              0            0.0             0.0            0.0
#
#          ramp_limit_down  ramp_limit_start_up  ramp_limit_shut_down
# carrier
# biomass              0.0                  2.0                   2.0
# load                 0.0                 10.0                  10.0
# oil                  0.0                  1.0                   1.0
# onwind               0.0                 10.0                  10.0
# solar                0.0                 10.0                  10.0

# %%
n.stores_t.p.head()
# Out:
# Store                     BO 0 H2       BO 1 H2       BO 2 H2       BO 3 H2  \
# snapshot
# 2013-01-01 00:00:00 -9.962199e-17 -1.267899e-16 -1.343344e-16 -1.699127e-16
# 2013-01-01 06:00:00 -1.942829e-16 -2.012500e-16 -2.002489e-16 -2.554709e-16
# 2013-01-01 12:00:00  9.843070e-17  6.927606e-17  1.130466e-16  1.123409e-16
# 2013-01-01 18:00:00  1.551683e-16  1.102190e-16  1.516669e-16  1.603061e-16
# 2013-01-02 00:00:00 -1.062938e-16 -7.541109e-17 -2.537998e-17 -9.483271e-17
#
# Store                     BO 4 H2       BO 5 H2       BO 6 H2       BO 7 H2  \
# snapshot
# 2013-01-01 00:00:00  1.631434e-16 -1.360527e-16 -5.098596e-16 -8.041082e-17
# 2013-01-01 06:00:00  2.165456e-16 -2.370958e-16 -7.187005e-16 -8.877009e-17
# 2013-01-01 12:00:00  2.629807e-16  7.468415e-17  7.301983e-17  3.923713e-17
# 2013-01-01 18:00:00  2.236383e-16  1.092807e-16  2.204313e-16  4.766880e-17
# 2013-01-02 00:00:00  1.645500e-16 -8.801226e-17 -2.294789e-16 -5.614199e-17
#
# Store                     BO 8 H2       BO 9 H2  BO 0 battery  BO 1 battery  \
# snapshot
# 2013-01-01 00:00:00 -8.702950e-18 -3.183841e-17 -2.668186e-15 -2.322444e-15
# 2013-01-01 06:00:00 -7.484634e-18 -8.932712e-18  1.040702e-15  9.378853e-17
# 2013-01-01 12:00:00 -7.744322e-18 -2.991730e-18  1.315009e-16  6.971935e-17
# 2013-01-01 18:00:00 -6.956568e-18  2.075579e-19 -1.087161e-15 -1.215995e-15
# 2013-01-02 00:00:00 -9.174058e-18 -3.170519e-17 -3.350960e-15 -2.837515e-15
#
# Store                BO 2 battery  BO 3 battery  BO 4 battery  BO 5 battery  \
# snapshot
# 2013-01-01 00:00:00 -3.010093e-15 -2.844953e-15 -8.739304e-16 -2.025614e-15
# 2013-01-01 06:00:00 -5.195736e-16  6.215176e-16  2.553099e-16  5.631372e-16
# 2013-01-01 12:00:00  3.928894e-16  1.309297e-16 -3.212242e-17 -3.253269e-16
# 2013-01-01 18:00:00 -4.593161e-16 -1.005862e-15 -4.970993e-16 -1.610775e-15
# 2013-01-02 00:00:00 -3.289588e-15 -3.309604e-15 -2.112118e-15 -2.708943e-15
#
# Store                BO 6 battery  BO 7 battery  BO 8 battery  BO 9 battery
# snapshot
# 2013-01-01 00:00:00 -2.101263e-15 -2.727613e-15 -4.937271e-17 -2.298902e-15
# 2013-01-01 06:00:00  5.442423e-16  5.315997e-16  8.547583e-18 -2.135783e-15
# 2013-01-01 12:00:00 -2.897781e-16  3.338052e-16  3.900308e-17  2.029716e-15
# 2013-01-01 18:00:00 -1.545610e-15 -7.163175e-16  6.072281e-17  2.479298e-15
# 2013-01-02 00:00:00 -2.734274e-15 -3.265642e-15 -1.800172e-17 -2.261295e-15

# %%
n.generators_t.p_max_pu.groupby(n.generators.carrier, axis=1).mean().plot()
# Out:
# <AxesSubplot:xlabel='snapshot'>

# %%
# If 0, all renewable capacity potential is used
n.generators.p_nom_max.sum() - n.generators.p_nom_opt.sum()
# Out:
# inf

# %%
n.loads_t.p.sum().sum()
# Out:
# 802471.0199702531

# %%
n.generators_t.p.sum().sum()
# Out:
# 275172220.3630748

# %%
#### pq la multiplicacion?

n.generators.iloc[:, :].groupby(["bus", "carrier"]).p_nom.sum() * 0.0000003
# Out:
# bus   carrier
# BO 0  load       3.000000e+02
#       onwind     6.559479e-08
#       solar      3.271149e-06
# BO 1  load       3.000000e+02
#       onwind     0.000000e+00
#       solar      6.416477e-07
# BO 2  biomass    2.168700e-05
#       load       3.000000e+02
#       onwind     3.656775e-06
#       solar      3.380796e-06
# BO 3  load       3.000000e+02
#       onwind     1.953577e-06
#       solar      1.502944e-05
# BO 4  biomass    1.482000e-06
#       load       3.000000e+02
#       oil        3.522000e-06
#       onwind     1.681481e-06
#       solar      5.814411e-06
# BO 5  load       3.000000e+02
#       onwind     3.121608e-07
#       solar      6.799367e-06
# BO 6  load       3.000000e+02
#       onwind     0.000000e+00
#       solar      3.060554e-07
# BO 7  load       3.000000e+02
#       onwind     1.198242e-07
#       solar      3.911166e-07
# BO 8  load       3.000000e+02
#       onwind     0.000000e+00
#       solar      0.000000e+00
# BO 9  load       3.000000e+02
#       onwind     0.000000e+00
#       solar      1.229392e-07
# Name: p_nom, dtype: float64

# %%
fig, ax = plt.subplots(
    figsize=(10, 10),
    subplot_kw={
        "projection": ccrs.PlateCarree()
    },  # PlateCarree(default), Mercator, Orthographic
)

# loading = (n3.lines_t.p0.abs().mean().sort_index() / (n3.lines.s_nom_opt*n.lines.s_max_pu).sort_index()).fillna(0.)

n.plot(
    margin=0.1,
    ax=None,
    geomap=True,  #'10m' leads to a beautiful high resolution map
    projection=None,
    bus_colors="cadetblue",
    bus_alpha=1,
    bus_sizes=normalize_node_size(
        n.generators.iloc[:, :].groupby(["bus", "carrier"]).p_nom_opt.sum()),
    bus_cmap=None,
    line_colors="rosybrown",
    link_colors="darkseagreen",  # loading
    transformer_colors="orange",
    line_widths=n.lines.s_nom_opt / 3e2,
    link_widths=1.5,
    transformer_widths=1.5,
    line_cmap=None,
    link_cmap=None,  # plt.cm.virdis (colordmap for line loading)
    transformer_cmap=None,
    flow=None,
    branch_components=None,
    layouter=None,
    title="Generator Map",
    boundaries=None,
    geometry=False,
    jitter=None,
    color_geomap=True,
)  # None or True

ax.axis("off");
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[22], line 10
#       1 fig, ax = plt.subplots(
#       2     figsize=(10, 10),
#       3     subplot_kw={
#       4         "projection": ccrs.PlateCarree()
#       5     },  # PlateCarree(default), Mercator, Orthographic
#       6 )
#       8 # loading = (n3.lines_t.p0.abs().mean().sort_index() / (n3.lines.s_nom_opt*n.lines.s_max_pu).sort_index()).fillna(0.)
# ---> 10 n.plot(
#      11     margin=0.1,
#      12     ax=None,
#      13     geomap=True,  #'10m' leads to a beautiful high resolution map
#      14     projection=None,
#      15     bus_colors="cadetblue",
#      16     bus_alpha=1,
#      17     bus_sizes=normalize_node_size(
#      18         n.generators.iloc[:, :].groupby(["bus", "carrier"]).p_nom_opt.sum()),
#      19     bus_cmap=None,
#      20     line_colors="rosybrown",
#      21     link_colors="darkseagreen",  # loading
#      22     transformer_colors="orange",
#      23     line_widths=n.lines.s_nom_opt / 3e2,
#      24     link_widths=1.5,
#      25     transformer_widths=1.5,
#      26     line_cmap=None,
#      27     link_cmap=None,  # plt.cm.virdis (colordmap for line loading)
#      28     transformer_cmap=None,
#      29     flow=None,
#      30     branch_components=None,
#      31     layouter=None,
#      32     title="Generator Map",
#      33     boundaries=None,
#      34     geometry=False,
#      35     jitter=None,
#      36     color_geomap=True,
#      37 )  # None or True
#      39 ax.axis("off");
#
# File c:\Users\Lenovo\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\plot.py:249, in plot(n, margin, ax, geomap, projection, bus_colors, bus_alpha, bus_sizes, bus_cmap, bus_norm, line_colors, link_colors, transformer_colors, line_alpha, link_alpha, transformer_alpha, line_widths, link_widths, transformer_widths, line_cmap, link_cmap, transformer_cmap, line_norm, link_norm, transformer_norm, flow, branch_components, layouter, title, boundaries, geometry, jitter, color_geomap)
#     247 if not isinstance(bus_colors, pd.Series):
#     248     bus_colors = n.carriers.color.dropna()
# --> 249 assert bus_sizes.index.levels[1].isin(bus_colors.index).all(), (
#     250     "Colors not defined for all elements in the second MultiIndex "
#     251     "level of bus_sizes, please make sure that all the elements are "
#     252     "included in bus_colors or in n.carriers.color"
#     253 )
#     255 bus_sizes = bus_sizes.sort_index(level=0, sort_remaining=False)
#     256 if geomap:
#
# AssertionError: Colors not defined for all elements in the second MultiIndex level of bus_sizes, please make sure that all the elements are included in bus_colors or in n.carriers.color

# %% [markdown]
# ### Demand

# %%
print(type(n.generators.iloc[:, :].groupby(["bus"]).p_nom_opt.sum()))

print(n.generators.iloc[:, :].groupby(["bus"]).p_nom_opt.sum())
# Out:
# <class 'pandas.core.series.Series'>
# bus
# BO 0    1.000000e+09
# BO 1    1.000000e+09
# BO 2    1.000000e+09
# BO 3    1.000000e+09
# BO 4    1.000003e+09
# BO 5    1.000000e+09
# BO 6    1.000002e+09
# BO 7    1.000000e+09
# BO 8    1.000000e+09
# BO 9    1.000000e+09
# Name: p_nom_opt, dtype: float64

# %%
n.loads_t.p_set.loc["2013-01-01":"2013-06-06","BO 0"].plot()
# Out:
# <AxesSubplot:xlabel='snapshot'>

# %%
type(n.loads_t.p_set.sum())
# Out:
# pandas.core.series.Series

# %%
a = n.loads_t.p_set.sum().rename("load").rename_axis("bus")
a.rename("load", inplace=True)
a.rename_axis("bus", inplace=True)
a
# Out:
# bus
# BO 0    165760.688502
# BO 1     81159.348527
# BO 2    191724.571497
# BO 3     66017.013065
# BO 4    149443.435993
# BO 5     48288.153868
# BO 6     73000.693259
# BO 7      1794.942286
# BO 8     18036.350625
# BO 9      7245.822349
# Name: load, dtype: float64

# %%
n.generators.iloc[:, :].groupby(["bus"]).p_nom_opt.sum()

###### potencia maxima?
#n.generators.iloc[:, :].groupby(["bus"]).p_max_pu.sum()
# Out:
# bus
# BO 0    1.000000e+09
# BO 1    1.000000e+09
# BO 2    1.000000e+09
# BO 3    1.000000e+09
# BO 4    1.000003e+09
# BO 5    1.000000e+09
# BO 6    1.000002e+09
# BO 7    1.000000e+09
# BO 8    1.000000e+09
# BO 9    1.000000e+09
# Name: p_nom_opt, dtype: float64

# %%
fig, ax = plt.subplots(
    figsize=(10, 10),
    subplot_kw={
        "projection": ccrs.PlateCarree()
    },  # PlateCarree(default), Mercator, Orthographic
)

# loading = (n3.lines_t.p0.abs().mean().sort_index() / (n3.lines.s_nom_opt*n.lines.s_max_pu).sort_index()).fillna(0.)

n.plot(
    margin=0.1,
    ax=None,
    geomap=True,  #'10m' leads to a beautiful high resolution map
    projection=None,
    bus_colors="cadetblue",
    bus_alpha=1,
    bus_sizes=normalize_node_size(
        n.loads_t.p_set.sum().rename("load").rename_axis("bus")
    ),  # n.loads_t.p_set.sum().rename("load").rename_axis("bus")*.0000003,
    bus_cmap=None,
    line_colors="rosybrown",
    link_colors="darkseagreen",  # loading
    transformer_colors="orange",
    line_widths=n.lines.s_nom_opt / 3000000000e2,
    link_widths=1.5,
    transformer_widths=1.5,
    line_cmap=None,
    link_cmap=None,  # plt.cm.virdis (colordmap for line loading)
    transformer_cmap=None,
    flow=None,
    branch_components=None,
    layouter=None,
    title="Generator Map",
    boundaries=None,
    geometry=False,
    jitter=None,
    color_geomap=True,
)  # None or True

ax.axis("off");

# %%
# backup
gen_serie = n.generators.iloc[:, :].groupby(["bus", "carrier"]).p_nom_opt.sum()
load_serie = n.loads_t.p_set.sum().rename("load").rename_axis("bus")

load_serie = pd.Series(
    load_serie.values,
    index=pd.MultiIndex.from_tuples([(id, "AC load") for id in load_serie.index]),
)

tot_serie = pd.concat([gen_serie, load_serie])  # .groupby(['bus', 'carrier']).sum()

pd.concat([gen_serie, load_serie])
# Out:
# bus   carrier
# BO 0  OCGT       3.535640e+02
#       load       1.000000e+09
#       onwind     1.218930e+01
#       solar      1.126941e+01
# BO 1  OCGT       7.224898e+01
#       load       1.000000e+09
#       onwind     2.186599e-01
#       ror        2.607215e+02
#       solar      1.090423e+01
# BO 2  OCGT       1.078072e+02
#       load       1.000000e+09
#       oil        3.399651e+01
#       onwind     6.511956e+00
#       solar      4.635814e+01
# BO 3  OCGT       1.498342e+02
#       load       1.000000e+09
#       onwind     3.850991e-05
#       ror        8.328479e+01
#       solar      3.159106e+00
# BO 4  load       1.000000e+09
#       onwind     5.604957e+00
#       solar      3.059832e+03
# BO 5  OCGT       2.179503e+02
#       load       1.000000e+09
#       onwind     3.995894e-01
#       solar      1.303728e+00
# BO 6  load       1.000000e+09
#       onwind     1.040557e+00
#       solar      1.637178e+03
# BO 7  load       1.000000e+09
#       onwind     6.234531e-05
#       solar      2.688550e+01
# BO 8  load       1.000000e+09
#       onwind     2.520803e-06
#       solar      4.563136e+02
# BO 9  OCGT       1.293689e+01
#       load       1.000000e+09
#       onwind     1.198507e-04
#       solar      3.742515e+00
# BO 0  AC load    1.657607e+05
# BO 1  AC load    8.115935e+04
# BO 2  AC load    1.917246e+05
# BO 3  AC load    6.601701e+04
# BO 4  AC load    1.494434e+05
# BO 5  AC load    4.828815e+04
# BO 6  AC load    7.300069e+04
# BO 7  AC load    1.794942e+03
# BO 8  AC load    1.803635e+04
# BO 9  AC load    7.245822e+03
# dtype: float64

# %% [markdown]
# ### Plot of Average Marginal Price

# %%
now = n.snapshots[4]  ##one specific time

fig, ax = plt.subplots(1, 1, subplot_kw={"projection": ccrs.PlateCarree()})
fig.set_size_inches(6, 4)

n.plot(ax=ax, line_widths=pd.Series(0.5, n.lines.index))
plt.hexbin(
    n.buses.x,
    n.buses.y,
    gridsize=20,
    # C=n.buses_t.marginal_price.loc[now], #at one time (previous set up by scigrid)
    C=n.buses_t.marginal_price.sum()
    / len(n.snapshots[:]),  # Marginal price averaged over the whole year (My version)
    # - shows in which regions electricity will be cheap and where el. intensive companies should be placed.
    cmap=plt.cm.jet,
)

# for some reason the colorbar only works with graphs plt.plot
# and must be attached plt.colorbar

cb = plt.colorbar()
cb.set_label("Locational Marginal Price (EUR/MWh)")

# %% [markdown]
# ### Storage

# %%
n.stores_t.e.loc["2013-01-01":"2013-06-01"].sum(axis=1).plot()
# Out:
# <AxesSubplot:xlabel='snapshot'>

# %%
n.links.iloc[:].groupby(["carrier"]).p_nom_opt.sum()
# Out:
# carrier
# H2 electrolysis       779.227504
# H2 fuel cell          482.534463
# battery charger         0.017229
# battery discharger      0.019144
# Name: p_nom_opt, dtype: float64
