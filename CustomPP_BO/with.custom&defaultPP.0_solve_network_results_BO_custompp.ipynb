# %% [markdown]
# # Plotting PyPSA results (adapted for the First Run of Bolivia - config.yaml file)
#
# ### Adele will check for additional results that can be used

# %%
###### algunas cosas cambian si pongo como comentarios en el import de geoviews y hvplot (liberias conflictivas?)

import logging
import os

import pypsa
import yaml
import pandas as pd
import geopandas as gpd
#import geoviews as gv
#import hvplot.pandas 
import numpy as np
import scipy as sp
import networkx as nx

# plotting stuff
import matplotlib.pyplot as plt

plt.style.use("bmh")
import seaborn as sns  ###
import cartopy.crs as ccrs

sns.set(style="darkgrid")

from scipy.sparse import csgraph
from itertools import product

from shapely.geometry import Point, LineString
import shapely, shapely.prepared, shapely.wkt

logger = logging.getLogger(__name__)

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 70)

import sys

sys.path.append("../")  # to import helpers
from scripts._helpers import sets_path_to_root

sets_path_to_root("pypsa-earth")

max_node_size = 1.0  # maximum size of a node for plotting purposes [used in plots]
# Out:
# This is the repository path:  c:\Users\Lenovo\Desktop\pypsa-earth
# Had to go 1 folder(s) up.

# %%
# utility function for nice plotting


def normalize_node_size(values, max_node_size=max_node_size):
    return values / values.max() * max_node_size

# %% [markdown]
# # Load all networks

# %%
# add_electricity_network = os.getcwd() + '/networks/elec.nc'
# n_add_el = pypsa.Network(add_electricity_network)

# clustered_network = os.getcwd() + '/networks/elec_s_20.nc'
# n_cluster = pypsa.Network(clustered_network)



#Se carga el documento (o la direccion/path del mismo) a una variable (solved_network)

solved_network = os.getcwd() + "/results/networks/elec_s_10_ec_lcopt_Co2L-6H.nc"

#Se cargan los resultados de la optimizacion del problema segun las caracteristicas definidas para el modelo en n_solve con la funcion (operador?) Network de pypsa

n_solve = pypsa.Network(solved_network)
# Out:
# INFO:pypsa.io:Imported network elec_s_10_ec_lcopt_Co2L-6H.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %% [markdown]
# # Solved network

# %%
n = n_solve

# %%
# ".global_constraints" muestra las restricciones consideradas para el modelo (en el config.yaml solo se tomo en cuenta el limite de emisiones) tonCO2/year

n.global_constraints
# Out:
#                  sense    constant            mu            type  \
# GlobalConstraint
# CO2Limit            <=  77500000.0  7.623424e-07  primary_energy
#
#                   investment_period carrier_attribute
# GlobalConstraint
# CO2Limit                        NaN     co2_emissions

# %%
#Calculo del precio promedio de energia promedio en la red (costo total de operacion)= ".objective" /  (sumatoria de las cargas variables en el tiempo)
# EURO/MWh

##### check why the value does not appear 
#   - It seems that while the model run before, due to restrictions on simulation, proper solving wasn't possible (by increasing tolerances of the solver the model gets actual results)


n.objective
# Out:
# 2221925037.840623

# %% [markdown]
# ### Spatial temporal resolution

# %%
#Resultado grafico de la red electrica ideal (lineas verdes representan expansiones de la red)

#####beacuase all buses are not connected it might be that the problem is not fully solved 
# - Lines used in the model don't consider newer power lines (data bases were not apdated)
# - This is proved by comparing raw lines (all available lines in OSM) and clean lines (processed lines to be used in the model)
# - A linker is required to include new/additional data into the "all_clean_lines.geojson"


n.plot()
# Out:
# (<matplotlib.collections.PatchCollection at 0x2416169f3d0>,
#  <matplotlib.collections.LineCollection at 0x24161772770>,
#  <matplotlib.collections.LineCollection at 0x241617726e0>)

# %%
#Se muestra el tamaño de la resolucion temporal del modelo - timesteps 
# - Currently the system is working with a toy version of Bolivia to allow faster solving times (6h time aggregation and a little over 5 months acoording the rules in the config.yaml file) 
# - A more complete model should be run eventually with different conditions (higher time resolution) or methods like tsam (https://tsam.readthedocs.io/en/latest/mathematicalBackgroundDoc.html)
#  

len(n.snapshots)
# Out:
# 624

# %% [markdown]
# ### Overview components

# %%
#Imprimir la lista de componentes considerados en el dataframe creado

for c in n.iterate_components(list(n.components.keys())[2:]):
    print("Component '{}' has {} entries".format(c.name, len(c.df)))
# Out:
# Component 'Bus' has 30 entries
# Component 'Carrier' has 16 entries
# Component 'GlobalConstraint' has 1 entries
# Component 'Line' has 8 entries
# Component 'LineType' has 34 entries
# Component 'TransformerType' has 14 entries
# Component 'Link' has 40 entries
# Component 'Load' has 10 entries
# Component 'Generator' has 41 entries
# Component 'StorageUnit' has 5 entries
# Component 'Store' has 20 entries

# %% [markdown]
# ### Energy balance

# %%
# ".stores_t" hace referencia a la energia que se puede almacenar en un bus (se usa para definir otras tecnologias como storage)
# - https://pypsa.readthedocs.io/en/latest/components.html#store

n.stores_t.p.sum()
# Out:
# Store
# BO 0 H2        -2.081668e-17
# BO 1 H2        -4.857226e-17
# BO 2 H2         6.245005e-17
# BO 3 H2        -1.387779e-17
# BO 4 H2         0.000000e+00
# BO 5 H2         0.000000e+00
# BO 6 H2        -3.469447e-17
# BO 7 H2         7.632783e-17
# BO 8 H2         0.000000e+00
# BO 9 H2         0.000000e+00
# BO 0 battery    8.673617e-19
# BO 1 battery    6.938894e-18
# BO 2 battery    0.000000e+00
# BO 3 battery   -2.602085e-18
# BO 4 battery    0.000000e+00
# BO 5 battery    0.000000e+00
# BO 6 battery    5.204170e-18
# BO 7 battery   -7.806256e-18
# BO 8 battery    0.000000e+00
# BO 9 battery    0.000000e+00
# dtype: float64

# %%
# se imprimen todos los generadores considerados en el modelo

##### check if loadshedding is being used in the config.yaml file, at the solving section 
# - load shedding is represented in the model by the inclution on additional "load" generation/generators 


n.generators

print(type(n.generators))
print(n.generators.columns)
n.generators
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['p_nom_max', 'weight', 'p_nom', 'capital_cost', 'efficiency',
#        'p_nom_min', 'marginal_cost', 'bus', 'p_nom_extendable', 'carrier',
#        'control', 'p_nom_opt', 'sign', 'build_year', 'min_up_time',
#        'min_down_time', 'up_time_before', 'down_time_before', 'type',
#        'p_min_pu', 'p_max_pu', 'p_set', 'q_set', 'lifetime', 'committable',
#        'start_up_cost', 'shut_down_cost', 'ramp_limit_up', 'ramp_limit_down',
#        'ramp_limit_start_up', 'ramp_limit_shut_down'],
#       dtype='object')
#                  p_nom_max         weight         p_nom   capital_cost  \
# Generator
# BO 0 OCGT              inf       0.000000  3.535638e+02   47234.561404
# BO 0 biomass           inf       0.000000  7.229000e+01  278015.359506
# BO 0 onwind   5.872036e+05   59888.246048  1.218925e+01  109295.569252
# BO 0 solar    2.221573e+05   30992.064349  1.126932e+01   50855.958267
# BO 1 onwind   1.982455e+05    5754.541306  1.040536e+00  109295.569252
# BO 1 solar    3.039954e+05   61268.474745  2.266456e+01   50855.958267
# BO 2 OCGT              inf       0.000000  1.207441e+02   47234.561404
# BO 2 oil               inf       0.000000  3.399651e+01   38234.561404
# BO 2 onwind   6.009534e+05   26703.715966  6.511923e+00  109295.569252
# BO 2 solar    6.995203e+05  135071.632048  5.009812e+01   50855.958267
# BO 3 OCGT              inf       0.000000  7.224879e+01   47234.561404
# BO 3 onwind   1.288879e+05    1351.910844  2.186493e-01  109295.569252
# BO 3 ror               inf     260.721486  2.607215e+02  270940.715283
# BO 3 solar    1.612263e+05   30267.135767  1.090383e+01   50855.958267
# BO 4 biomass           inf       0.000000  4.940000e+00  278015.359506
# BO 4 oil               inf       0.000000  1.174000e+01   38234.561404
# BO 4 onwind   7.178415e+05   28760.831046  5.604937e+00  109295.569252
# BO 4 solar    3.910029e+05   52379.941288  1.938137e+01   50855.958267
# BO 5 OCGT              inf       0.000000  1.498340e+02   47234.561404
# BO 5 onwind   1.976328e+04      42.860109  0.000000e+00  109295.569252
# BO 5 solar    2.732353e+04    4539.321137  1.293474e+00   50855.958267
# BO 6 OCGT              inf       0.000000  2.179502e+02   47234.561404
# BO 6 onwind   3.675056e+04    1323.163883  2.619964e-01  109295.569252
# BO 6 solar    1.832031e+04    2558.384713  9.448228e-01   50855.958267
# BO 7 onwind   5.081660e+04     615.834070  1.374177e-01  109295.569252
# BO 7 ror               inf      83.284793  8.328479e+01  270940.715283
# BO 7 solar    3.925425e+04    6042.563660  2.224436e+00   50855.958267
# BO 8 onwind   3.894440e+03      38.728584  0.000000e+00  109295.569252
# BO 8 solar    6.051754e+03    1104.440890  4.097973e-01   50855.958267
# BO 9 onwind   3.169000e+04       6.538648  0.000000e+00  109295.569252
# BO 9 solar    7.799832e+02      94.299926  0.000000e+00   50855.958267
# BO 0 load              inf            NaN  1.000000e+09       0.000000
# BO 1 load              inf            NaN  1.000000e+09       0.000000
# BO 2 load              inf            NaN  1.000000e+09       0.000000
# BO 3 load              inf            NaN  1.000000e+09       0.000000
# BO 4 load              inf            NaN  1.000000e+09       0.000000
# BO 5 load              inf            NaN  1.000000e+09       0.000000
# BO 6 load              inf            NaN  1.000000e+09       0.000000
# BO 7 load              inf            NaN  1.000000e+09       0.000000
# BO 8 load              inf            NaN  1.000000e+09       0.000000
# BO 9 load              inf            NaN  1.000000e+09       0.000000
#
#               efficiency   p_nom_min  marginal_cost   bus  p_nom_extendable  \
# Generator
# BO 0 OCGT          0.390  353.563766      58.393835  BO 0              True
# BO 0 biomass       0.468   72.290000      14.967433  BO 0             False
# BO 0 onwind        1.000   12.189249       0.025173  BO 0             False
# BO 0 solar         1.000   11.269319       0.019092  BO 0             False
# BO 1 onwind        1.000    1.040536       0.025993  BO 1             False
# BO 1 solar         1.000   22.664558       0.019101  BO 1             False
# BO 2 OCGT          0.390  120.744063      58.394349  BO 2              True
# BO 2 oil           0.393   33.996513     130.237294  BO 2             False
# BO 2 onwind        1.000    6.511923       0.025097  BO 2             False
# BO 2 solar         1.000   50.098120       0.019239  BO 2             False
# BO 3 OCGT          0.390   72.248791      58.393676  BO 3              True
# BO 3 onwind        1.000    0.218649       0.025126  BO 3             False
# BO 3 ror           0.900    0.000000       0.010299  BO 3             False
# BO 3 solar         1.000   10.903831       0.019907  BO 3             False
# BO 4 biomass       0.468    4.940000      14.967114  BO 4             False
# BO 4 oil           0.393   11.740000     130.235787  BO 4             False
# BO 4 onwind        1.000    5.604937       0.025625  BO 4             False
# BO 4 solar         1.000   19.381369       0.019049  BO 4             False
# BO 5 OCGT          0.390  149.834039      58.393739  BO 5              True
# BO 5 onwind        1.000    0.000000       0.024889  BO 5             False
# BO 5 solar         1.000    1.293474       0.019100  BO 5             False
# BO 6 OCGT          0.390  217.950221      58.393750  BO 6              True
# BO 6 onwind        1.000    0.261996       0.024811  BO 6             False
# BO 6 solar         1.000    0.944823       0.020005  BO 6             False
# BO 7 onwind        1.000    0.137418       0.025797  BO 7             False
# BO 7 ror           0.900    0.000000       0.009455  BO 7             False
# BO 7 solar         1.000    2.224436       0.020577  BO 7             False
# BO 8 onwind        1.000    0.000000       0.025716  BO 8             False
# BO 8 solar         1.000    0.409797       0.020362  BO 8             False
# BO 9 onwind        1.000    0.000000       0.024586  BO 9             False
# BO 9 solar         1.000    0.000000       0.019401  BO 9             False
# BO 0 load          1.000    0.000000       1.010974  BO 0             False
# BO 1 load          1.000    0.000000       1.010328  BO 1             False
# BO 2 load          1.000    0.000000       1.009102  BO 2             False
# BO 3 load          1.000    0.000000       1.010125  BO 3             False
# BO 4 load          1.000    0.000000       1.010727  BO 4             False
# BO 5 load          1.000    0.000000       1.010350  BO 5             False
# BO 6 load          1.000    0.000000       1.009015  BO 6             False
# BO 7 load          1.000    0.000000       1.010538  BO 7             False
# BO 8 load          1.000    0.000000       1.010522  BO 8             False
# BO 9 load          1.000    0.000000       1.010818  BO 9             False
#
#               carrier control     p_nom_opt   sign  build_year  min_up_time  \
# Generator
# BO 0 OCGT        OCGT   Slack  3.535732e+02  1.000           0            0
# BO 0 biomass  biomass          7.229000e+01  1.000           0            0
# BO 0 onwind    onwind          1.218925e+01  1.000           0            0
# BO 0 solar      solar          1.126932e+01  1.000           0            0
# BO 1 onwind    onwind          1.040536e+00  1.000           0            0
# BO 1 solar      solar          2.266456e+01  1.000           0            0
# BO 2 OCGT        OCGT          1.207520e+02  1.000           0            0
# BO 2 oil          oil          3.399651e+01  1.000           0            0
# BO 2 onwind    onwind          6.511923e+00  1.000           0            0
# BO 2 solar      solar          5.009812e+01  1.000           0            0
# BO 3 OCGT        OCGT          7.225783e+01  1.000           0            0
# BO 3 onwind    onwind          2.186493e-01  1.000           0            0
# BO 3 ror          ror          2.607215e+02  1.000           0            0
# BO 3 solar      solar          1.090383e+01  1.000           0            0
# BO 4 biomass  biomass   Slack  4.940000e+00  1.000           0            0
# BO 4 oil          oil          1.174000e+01  1.000           0            0
# BO 4 onwind    onwind          5.604937e+00  1.000           0            0
# BO 4 solar      solar          1.938137e+01  1.000           0            0
# BO 5 OCGT        OCGT          1.498449e+02  1.000           0            0
# BO 5 onwind    onwind          0.000000e+00  1.000           0            0
# BO 5 solar      solar          1.293474e+00  1.000           0            0
# BO 6 OCGT        OCGT          2.179527e+02  1.000           0            0
# BO 6 onwind    onwind          2.619964e-01  1.000           0            0
# BO 6 solar      solar          9.448228e-01  1.000           0            0
# BO 7 onwind    onwind          1.374177e-01  1.000           0            0
# BO 7 ror          ror          8.328479e+01  1.000           0            0
# BO 7 solar      solar          2.224436e+00  1.000           0            0
# BO 8 onwind    onwind   Slack  0.000000e+00  1.000           0            0
# BO 8 solar      solar          4.097973e-01  1.000           0            0
# BO 9 onwind    onwind   Slack  0.000000e+00  1.000           0            0
# BO 9 solar      solar          0.000000e+00  1.000           0            0
# BO 0 load        load      PQ  1.000000e+09  0.001           0            0
# BO 1 load        load      PQ  1.000000e+09  0.001           0            0
# BO 2 load        load      PQ  1.000000e+09  0.001           0            0
# BO 3 load        load      PQ  1.000000e+09  0.001           0            0
# BO 4 load        load      PQ  1.000000e+09  0.001           0            0
# BO 5 load        load      PQ  1.000000e+09  0.001           0            0
# BO 6 load        load      PQ  1.000000e+09  0.001           0            0
# BO 7 load        load      PQ  1.000000e+09  0.001           0            0
# BO 8 load        load      PQ  1.000000e+09  0.001           0            0
# BO 9 load        load      PQ  1.000000e+09  0.001           0            0
#
#               min_down_time  up_time_before  down_time_before type  p_min_pu  \
# Generator
# BO 0 OCGT                 0               1                 0            0.0
# BO 0 biomass              0               1                 0            0.0
# BO 0 onwind               0               1                 0            0.0
# BO 0 solar                0               1                 0            0.0
# BO 1 onwind               0               1                 0            0.0
# BO 1 solar                0               1                 0            0.0
# BO 2 OCGT                 0               1                 0            0.0
# BO 2 oil                  0               1                 0            0.0
# BO 2 onwind               0               1                 0            0.0
# BO 2 solar                0               1                 0            0.0
# BO 3 OCGT                 0               1                 0            0.0
# BO 3 onwind               0               1                 0            0.0
# BO 3 ror                  0               1                 0            0.0
# BO 3 solar                0               1                 0            0.0
# BO 4 biomass              0               1                 0            0.0
# BO 4 oil                  0               1                 0            0.0
# BO 4 onwind               0               1                 0            0.0
# BO 4 solar                0               1                 0            0.0
# BO 5 OCGT                 0               1                 0            0.0
# BO 5 onwind               0               1                 0            0.0
# BO 5 solar                0               1                 0            0.0
# BO 6 OCGT                 0               1                 0            0.0
# BO 6 onwind               0               1                 0            0.0
# BO 6 solar                0               1                 0            0.0
# BO 7 onwind               0               1                 0            0.0
# BO 7 ror                  0               1                 0            0.0
# BO 7 solar                0               1                 0            0.0
# BO 8 onwind               0               1                 0            0.0
# BO 8 solar                0               1                 0            0.0
# BO 9 onwind               0               1                 0            0.0
# BO 9 solar                0               1                 0            0.0
# BO 0 load                 0               1                 0            0.0
# BO 1 load                 0               1                 0            0.0
# BO 2 load                 0               1                 0            0.0
# BO 3 load                 0               1                 0            0.0
# BO 4 load                 0               1                 0            0.0
# BO 5 load                 0               1                 0            0.0
# BO 6 load                 0               1                 0            0.0
# BO 7 load                 0               1                 0            0.0
# BO 8 load                 0               1                 0            0.0
# BO 9 load                 0               1                 0            0.0
#
#               p_max_pu  p_set  q_set  lifetime  committable  start_up_cost  \
# Generator
# BO 0 OCGT          1.0    0.0    0.0       inf        False            0.0
# BO 0 biomass       1.0    0.0    0.0       inf        False            0.0
# BO 0 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 0 solar         1.0    0.0    0.0       inf        False            0.0
# BO 1 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 1 solar         1.0    0.0    0.0       inf        False            0.0
# BO 2 OCGT          1.0    0.0    0.0       inf        False            0.0
# BO 2 oil           1.0    0.0    0.0       inf        False            0.0
# BO 2 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 2 solar         1.0    0.0    0.0       inf        False            0.0
# BO 3 OCGT          1.0    0.0    0.0       inf        False            0.0
# BO 3 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 3 ror           1.0    0.0    0.0       inf        False            0.0
# BO 3 solar         1.0    0.0    0.0       inf        False            0.0
# BO 4 biomass       1.0    0.0    0.0       inf        False            0.0
# BO 4 oil           1.0    0.0    0.0       inf        False            0.0
# BO 4 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 4 solar         1.0    0.0    0.0       inf        False            0.0
# BO 5 OCGT          1.0    0.0    0.0       inf        False            0.0
# BO 5 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 5 solar         1.0    0.0    0.0       inf        False            0.0
# BO 6 OCGT          1.0    0.0    0.0       inf        False            0.0
# BO 6 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 6 solar         1.0    0.0    0.0       inf        False            0.0
# BO 7 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 7 ror           1.0    0.0    0.0       inf        False            0.0
# BO 7 solar         1.0    0.0    0.0       inf        False            0.0
# BO 8 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 8 solar         1.0    0.0    0.0       inf        False            0.0
# BO 9 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 9 solar         1.0    0.0    0.0       inf        False            0.0
# BO 0 load          1.0    0.0    0.0       inf        False            0.0
# BO 1 load          1.0    0.0    0.0       inf        False            0.0
# BO 2 load          1.0    0.0    0.0       inf        False            0.0
# BO 3 load          1.0    0.0    0.0       inf        False            0.0
# BO 4 load          1.0    0.0    0.0       inf        False            0.0
# BO 5 load          1.0    0.0    0.0       inf        False            0.0
# BO 6 load          1.0    0.0    0.0       inf        False            0.0
# BO 7 load          1.0    0.0    0.0       inf        False            0.0
# BO 8 load          1.0    0.0    0.0       inf        False            0.0
# BO 9 load          1.0    0.0    0.0       inf        False            0.0
#
#               shut_down_cost  ramp_limit_up  ramp_limit_down  \
# Generator
# BO 0 OCGT                0.0            NaN              NaN
# BO 0 biomass             0.0            NaN              NaN
# BO 0 onwind              0.0            NaN              NaN
# BO 0 solar               0.0            NaN              NaN
# BO 1 onwind              0.0            NaN              NaN
# BO 1 solar               0.0            NaN              NaN
# BO 2 OCGT                0.0            NaN              NaN
# BO 2 oil                 0.0            NaN              NaN
# BO 2 onwind              0.0            NaN              NaN
# BO 2 solar               0.0            NaN              NaN
# BO 3 OCGT                0.0            NaN              NaN
# BO 3 onwind              0.0            NaN              NaN
# BO 3 ror                 0.0            NaN              NaN
# BO 3 solar               0.0            NaN              NaN
# BO 4 biomass             0.0            NaN              NaN
# BO 4 oil                 0.0            NaN              NaN
# BO 4 onwind              0.0            NaN              NaN
# BO 4 solar               0.0            NaN              NaN
# BO 5 OCGT                0.0            NaN              NaN
# BO 5 onwind              0.0            NaN              NaN
# BO 5 solar               0.0            NaN              NaN
# BO 6 OCGT                0.0            NaN              NaN
# BO 6 onwind              0.0            NaN              NaN
# BO 6 solar               0.0            NaN              NaN
# BO 7 onwind              0.0            NaN              NaN
# BO 7 ror                 0.0            NaN              NaN
# BO 7 solar               0.0            NaN              NaN
# BO 8 onwind              0.0            NaN              NaN
# BO 8 solar               0.0            NaN              NaN
# BO 9 onwind              0.0            NaN              NaN
# BO 9 solar               0.0            NaN              NaN
# BO 0 load                0.0            NaN              NaN
# BO 1 load                0.0            NaN              NaN
# BO 2 load                0.0            NaN              NaN
# BO 3 load                0.0            NaN              NaN
# BO 4 load                0.0            NaN              NaN
# BO 5 load                0.0            NaN              NaN
# BO 6 load                0.0            NaN              NaN
# BO 7 load                0.0            NaN              NaN
# BO 8 load                0.0            NaN              NaN
# BO 9 load                0.0            NaN              NaN
#
#               ramp_limit_start_up  ramp_limit_shut_down
# Generator
# BO 0 OCGT                     1.0                   1.0
# BO 0 biomass                  1.0                   1.0
# BO 0 onwind                   1.0                   1.0
# BO 0 solar                    1.0                   1.0
# BO 1 onwind                   1.0                   1.0
# BO 1 solar                    1.0                   1.0
# BO 2 OCGT                     1.0                   1.0
# BO 2 oil                      1.0                   1.0
# BO 2 onwind                   1.0                   1.0
# BO 2 solar                    1.0                   1.0
# BO 3 OCGT                     1.0                   1.0
# BO 3 onwind                   1.0                   1.0
# BO 3 ror                      1.0                   1.0
# BO 3 solar                    1.0                   1.0
# BO 4 biomass                  1.0                   1.0
# BO 4 oil                      1.0                   1.0
# BO 4 onwind                   1.0                   1.0
# BO 4 solar                    1.0                   1.0
# BO 5 OCGT                     1.0                   1.0
# BO 5 onwind                   1.0                   1.0
# BO 5 solar                    1.0                   1.0
# BO 6 OCGT                     1.0                   1.0
# BO 6 onwind                   1.0                   1.0
# BO 6 solar                    1.0                   1.0
# BO 7 onwind                   1.0                   1.0
# BO 7 ror                      1.0                   1.0
# BO 7 solar                    1.0                   1.0
# BO 8 onwind                   1.0                   1.0
# BO 8 solar                    1.0                   1.0
# BO 9 onwind                   1.0                   1.0
# BO 9 solar                    1.0                   1.0
# BO 0 load                     1.0                   1.0
# BO 1 load                     1.0                   1.0
# BO 2 load                     1.0                   1.0
# BO 3 load                     1.0                   1.0
# BO 4 load                     1.0                   1.0
# BO 5 load                     1.0                   1.0
# BO 6 load                     1.0                   1.0
# BO 7 load                     1.0                   1.0
# BO 8 load                     1.0                   1.0
# BO 9 load                     1.0                   1.0

# %%
#Imprimir solo los generadores de Bolivia

########(this is only necessary if several countries are studied at the same time

idx = ['BO' in x for x in n.generators.index]
n.generators.loc[idx,:]
# Out:
#                  p_nom_max         weight         p_nom   capital_cost  \
# Generator
# BO 0 OCGT              inf       0.000000  3.535638e+02   47234.561404
# BO 0 biomass           inf       0.000000  7.229000e+01  278015.359506
# BO 0 onwind   5.872036e+05   59888.246048  1.218925e+01  109295.569252
# BO 0 solar    2.221573e+05   30992.064349  1.126932e+01   50855.958267
# BO 1 onwind   1.982455e+05    5754.541306  1.040536e+00  109295.569252
# BO 1 solar    3.039954e+05   61268.474745  2.266456e+01   50855.958267
# BO 2 OCGT              inf       0.000000  1.207441e+02   47234.561404
# BO 2 oil               inf       0.000000  3.399651e+01   38234.561404
# BO 2 onwind   6.009534e+05   26703.715966  6.511923e+00  109295.569252
# BO 2 solar    6.995203e+05  135071.632048  5.009812e+01   50855.958267
# BO 3 OCGT              inf       0.000000  7.224879e+01   47234.561404
# BO 3 onwind   1.288879e+05    1351.910844  2.186493e-01  109295.569252
# BO 3 ror               inf     260.721486  2.607215e+02  270940.715283
# BO 3 solar    1.612263e+05   30267.135767  1.090383e+01   50855.958267
# BO 4 biomass           inf       0.000000  4.940000e+00  278015.359506
# BO 4 oil               inf       0.000000  1.174000e+01   38234.561404
# BO 4 onwind   7.178415e+05   28760.831046  5.604937e+00  109295.569252
# BO 4 solar    3.910029e+05   52379.941288  1.938137e+01   50855.958267
# BO 5 OCGT              inf       0.000000  1.498340e+02   47234.561404
# BO 5 onwind   1.976328e+04      42.860109  0.000000e+00  109295.569252
# BO 5 solar    2.732353e+04    4539.321137  1.293474e+00   50855.958267
# BO 6 OCGT              inf       0.000000  2.179502e+02   47234.561404
# BO 6 onwind   3.675056e+04    1323.163883  2.619964e-01  109295.569252
# BO 6 solar    1.832031e+04    2558.384713  9.448228e-01   50855.958267
# BO 7 onwind   5.081660e+04     615.834070  1.374177e-01  109295.569252
# BO 7 ror               inf      83.284793  8.328479e+01  270940.715283
# BO 7 solar    3.925425e+04    6042.563660  2.224436e+00   50855.958267
# BO 8 onwind   3.894440e+03      38.728584  0.000000e+00  109295.569252
# BO 8 solar    6.051754e+03    1104.440890  4.097973e-01   50855.958267
# BO 9 onwind   3.169000e+04       6.538648  0.000000e+00  109295.569252
# BO 9 solar    7.799832e+02      94.299926  0.000000e+00   50855.958267
# BO 0 load              inf            NaN  1.000000e+09       0.000000
# BO 1 load              inf            NaN  1.000000e+09       0.000000
# BO 2 load              inf            NaN  1.000000e+09       0.000000
# BO 3 load              inf            NaN  1.000000e+09       0.000000
# BO 4 load              inf            NaN  1.000000e+09       0.000000
# BO 5 load              inf            NaN  1.000000e+09       0.000000
# BO 6 load              inf            NaN  1.000000e+09       0.000000
# BO 7 load              inf            NaN  1.000000e+09       0.000000
# BO 8 load              inf            NaN  1.000000e+09       0.000000
# BO 9 load              inf            NaN  1.000000e+09       0.000000
#
#               efficiency   p_nom_min  marginal_cost   bus  p_nom_extendable  \
# Generator
# BO 0 OCGT          0.390  353.563766      58.393835  BO 0              True
# BO 0 biomass       0.468   72.290000      14.967433  BO 0             False
# BO 0 onwind        1.000   12.189249       0.025173  BO 0             False
# BO 0 solar         1.000   11.269319       0.019092  BO 0             False
# BO 1 onwind        1.000    1.040536       0.025993  BO 1             False
# BO 1 solar         1.000   22.664558       0.019101  BO 1             False
# BO 2 OCGT          0.390  120.744063      58.394349  BO 2              True
# BO 2 oil           0.393   33.996513     130.237294  BO 2             False
# BO 2 onwind        1.000    6.511923       0.025097  BO 2             False
# BO 2 solar         1.000   50.098120       0.019239  BO 2             False
# BO 3 OCGT          0.390   72.248791      58.393676  BO 3              True
# BO 3 onwind        1.000    0.218649       0.025126  BO 3             False
# BO 3 ror           0.900    0.000000       0.010299  BO 3             False
# BO 3 solar         1.000   10.903831       0.019907  BO 3             False
# BO 4 biomass       0.468    4.940000      14.967114  BO 4             False
# BO 4 oil           0.393   11.740000     130.235787  BO 4             False
# BO 4 onwind        1.000    5.604937       0.025625  BO 4             False
# BO 4 solar         1.000   19.381369       0.019049  BO 4             False
# BO 5 OCGT          0.390  149.834039      58.393739  BO 5              True
# BO 5 onwind        1.000    0.000000       0.024889  BO 5             False
# BO 5 solar         1.000    1.293474       0.019100  BO 5             False
# BO 6 OCGT          0.390  217.950221      58.393750  BO 6              True
# BO 6 onwind        1.000    0.261996       0.024811  BO 6             False
# BO 6 solar         1.000    0.944823       0.020005  BO 6             False
# BO 7 onwind        1.000    0.137418       0.025797  BO 7             False
# BO 7 ror           0.900    0.000000       0.009455  BO 7             False
# BO 7 solar         1.000    2.224436       0.020577  BO 7             False
# BO 8 onwind        1.000    0.000000       0.025716  BO 8             False
# BO 8 solar         1.000    0.409797       0.020362  BO 8             False
# BO 9 onwind        1.000    0.000000       0.024586  BO 9             False
# BO 9 solar         1.000    0.000000       0.019401  BO 9             False
# BO 0 load          1.000    0.000000       1.010974  BO 0             False
# BO 1 load          1.000    0.000000       1.010328  BO 1             False
# BO 2 load          1.000    0.000000       1.009102  BO 2             False
# BO 3 load          1.000    0.000000       1.010125  BO 3             False
# BO 4 load          1.000    0.000000       1.010727  BO 4             False
# BO 5 load          1.000    0.000000       1.010350  BO 5             False
# BO 6 load          1.000    0.000000       1.009015  BO 6             False
# BO 7 load          1.000    0.000000       1.010538  BO 7             False
# BO 8 load          1.000    0.000000       1.010522  BO 8             False
# BO 9 load          1.000    0.000000       1.010818  BO 9             False
#
#               carrier control     p_nom_opt   sign  build_year  min_up_time  \
# Generator
# BO 0 OCGT        OCGT   Slack  3.535732e+02  1.000           0            0
# BO 0 biomass  biomass          7.229000e+01  1.000           0            0
# BO 0 onwind    onwind          1.218925e+01  1.000           0            0
# BO 0 solar      solar          1.126932e+01  1.000           0            0
# BO 1 onwind    onwind          1.040536e+00  1.000           0            0
# BO 1 solar      solar          2.266456e+01  1.000           0            0
# BO 2 OCGT        OCGT          1.207520e+02  1.000           0            0
# BO 2 oil          oil          3.399651e+01  1.000           0            0
# BO 2 onwind    onwind          6.511923e+00  1.000           0            0
# BO 2 solar      solar          5.009812e+01  1.000           0            0
# BO 3 OCGT        OCGT          7.225783e+01  1.000           0            0
# BO 3 onwind    onwind          2.186493e-01  1.000           0            0
# BO 3 ror          ror          2.607215e+02  1.000           0            0
# BO 3 solar      solar          1.090383e+01  1.000           0            0
# BO 4 biomass  biomass   Slack  4.940000e+00  1.000           0            0
# BO 4 oil          oil          1.174000e+01  1.000           0            0
# BO 4 onwind    onwind          5.604937e+00  1.000           0            0
# BO 4 solar      solar          1.938137e+01  1.000           0            0
# BO 5 OCGT        OCGT          1.498449e+02  1.000           0            0
# BO 5 onwind    onwind          0.000000e+00  1.000           0            0
# BO 5 solar      solar          1.293474e+00  1.000           0            0
# BO 6 OCGT        OCGT          2.179527e+02  1.000           0            0
# BO 6 onwind    onwind          2.619964e-01  1.000           0            0
# BO 6 solar      solar          9.448228e-01  1.000           0            0
# BO 7 onwind    onwind          1.374177e-01  1.000           0            0
# BO 7 ror          ror          8.328479e+01  1.000           0            0
# BO 7 solar      solar          2.224436e+00  1.000           0            0
# BO 8 onwind    onwind   Slack  0.000000e+00  1.000           0            0
# BO 8 solar      solar          4.097973e-01  1.000           0            0
# BO 9 onwind    onwind   Slack  0.000000e+00  1.000           0            0
# BO 9 solar      solar          0.000000e+00  1.000           0            0
# BO 0 load        load      PQ  1.000000e+09  0.001           0            0
# BO 1 load        load      PQ  1.000000e+09  0.001           0            0
# BO 2 load        load      PQ  1.000000e+09  0.001           0            0
# BO 3 load        load      PQ  1.000000e+09  0.001           0            0
# BO 4 load        load      PQ  1.000000e+09  0.001           0            0
# BO 5 load        load      PQ  1.000000e+09  0.001           0            0
# BO 6 load        load      PQ  1.000000e+09  0.001           0            0
# BO 7 load        load      PQ  1.000000e+09  0.001           0            0
# BO 8 load        load      PQ  1.000000e+09  0.001           0            0
# BO 9 load        load      PQ  1.000000e+09  0.001           0            0
#
#               min_down_time  up_time_before  down_time_before type  p_min_pu  \
# Generator
# BO 0 OCGT                 0               1                 0            0.0
# BO 0 biomass              0               1                 0            0.0
# BO 0 onwind               0               1                 0            0.0
# BO 0 solar                0               1                 0            0.0
# BO 1 onwind               0               1                 0            0.0
# BO 1 solar                0               1                 0            0.0
# BO 2 OCGT                 0               1                 0            0.0
# BO 2 oil                  0               1                 0            0.0
# BO 2 onwind               0               1                 0            0.0
# BO 2 solar                0               1                 0            0.0
# BO 3 OCGT                 0               1                 0            0.0
# BO 3 onwind               0               1                 0            0.0
# BO 3 ror                  0               1                 0            0.0
# BO 3 solar                0               1                 0            0.0
# BO 4 biomass              0               1                 0            0.0
# BO 4 oil                  0               1                 0            0.0
# BO 4 onwind               0               1                 0            0.0
# BO 4 solar                0               1                 0            0.0
# BO 5 OCGT                 0               1                 0            0.0
# BO 5 onwind               0               1                 0            0.0
# BO 5 solar                0               1                 0            0.0
# BO 6 OCGT                 0               1                 0            0.0
# BO 6 onwind               0               1                 0            0.0
# BO 6 solar                0               1                 0            0.0
# BO 7 onwind               0               1                 0            0.0
# BO 7 ror                  0               1                 0            0.0
# BO 7 solar                0               1                 0            0.0
# BO 8 onwind               0               1                 0            0.0
# BO 8 solar                0               1                 0            0.0
# BO 9 onwind               0               1                 0            0.0
# BO 9 solar                0               1                 0            0.0
# BO 0 load                 0               1                 0            0.0
# BO 1 load                 0               1                 0            0.0
# BO 2 load                 0               1                 0            0.0
# BO 3 load                 0               1                 0            0.0
# BO 4 load                 0               1                 0            0.0
# BO 5 load                 0               1                 0            0.0
# BO 6 load                 0               1                 0            0.0
# BO 7 load                 0               1                 0            0.0
# BO 8 load                 0               1                 0            0.0
# BO 9 load                 0               1                 0            0.0
#
#               p_max_pu  p_set  q_set  lifetime  committable  start_up_cost  \
# Generator
# BO 0 OCGT          1.0    0.0    0.0       inf        False            0.0
# BO 0 biomass       1.0    0.0    0.0       inf        False            0.0
# BO 0 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 0 solar         1.0    0.0    0.0       inf        False            0.0
# BO 1 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 1 solar         1.0    0.0    0.0       inf        False            0.0
# BO 2 OCGT          1.0    0.0    0.0       inf        False            0.0
# BO 2 oil           1.0    0.0    0.0       inf        False            0.0
# BO 2 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 2 solar         1.0    0.0    0.0       inf        False            0.0
# BO 3 OCGT          1.0    0.0    0.0       inf        False            0.0
# BO 3 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 3 ror           1.0    0.0    0.0       inf        False            0.0
# BO 3 solar         1.0    0.0    0.0       inf        False            0.0
# BO 4 biomass       1.0    0.0    0.0       inf        False            0.0
# BO 4 oil           1.0    0.0    0.0       inf        False            0.0
# BO 4 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 4 solar         1.0    0.0    0.0       inf        False            0.0
# BO 5 OCGT          1.0    0.0    0.0       inf        False            0.0
# BO 5 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 5 solar         1.0    0.0    0.0       inf        False            0.0
# BO 6 OCGT          1.0    0.0    0.0       inf        False            0.0
# BO 6 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 6 solar         1.0    0.0    0.0       inf        False            0.0
# BO 7 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 7 ror           1.0    0.0    0.0       inf        False            0.0
# BO 7 solar         1.0    0.0    0.0       inf        False            0.0
# BO 8 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 8 solar         1.0    0.0    0.0       inf        False            0.0
# BO 9 onwind        1.0    0.0    0.0       inf        False            0.0
# BO 9 solar         1.0    0.0    0.0       inf        False            0.0
# BO 0 load          1.0    0.0    0.0       inf        False            0.0
# BO 1 load          1.0    0.0    0.0       inf        False            0.0
# BO 2 load          1.0    0.0    0.0       inf        False            0.0
# BO 3 load          1.0    0.0    0.0       inf        False            0.0
# BO 4 load          1.0    0.0    0.0       inf        False            0.0
# BO 5 load          1.0    0.0    0.0       inf        False            0.0
# BO 6 load          1.0    0.0    0.0       inf        False            0.0
# BO 7 load          1.0    0.0    0.0       inf        False            0.0
# BO 8 load          1.0    0.0    0.0       inf        False            0.0
# BO 9 load          1.0    0.0    0.0       inf        False            0.0
#
#               shut_down_cost  ramp_limit_up  ramp_limit_down  \
# Generator
# BO 0 OCGT                0.0            NaN              NaN
# BO 0 biomass             0.0            NaN              NaN
# BO 0 onwind              0.0            NaN              NaN
# BO 0 solar               0.0            NaN              NaN
# BO 1 onwind              0.0            NaN              NaN
# BO 1 solar               0.0            NaN              NaN
# BO 2 OCGT                0.0            NaN              NaN
# BO 2 oil                 0.0            NaN              NaN
# BO 2 onwind              0.0            NaN              NaN
# BO 2 solar               0.0            NaN              NaN
# BO 3 OCGT                0.0            NaN              NaN
# BO 3 onwind              0.0            NaN              NaN
# BO 3 ror                 0.0            NaN              NaN
# BO 3 solar               0.0            NaN              NaN
# BO 4 biomass             0.0            NaN              NaN
# BO 4 oil                 0.0            NaN              NaN
# BO 4 onwind              0.0            NaN              NaN
# BO 4 solar               0.0            NaN              NaN
# BO 5 OCGT                0.0            NaN              NaN
# BO 5 onwind              0.0            NaN              NaN
# BO 5 solar               0.0            NaN              NaN
# BO 6 OCGT                0.0            NaN              NaN
# BO 6 onwind              0.0            NaN              NaN
# BO 6 solar               0.0            NaN              NaN
# BO 7 onwind              0.0            NaN              NaN
# BO 7 ror                 0.0            NaN              NaN
# BO 7 solar               0.0            NaN              NaN
# BO 8 onwind              0.0            NaN              NaN
# BO 8 solar               0.0            NaN              NaN
# BO 9 onwind              0.0            NaN              NaN
# BO 9 solar               0.0            NaN              NaN
# BO 0 load                0.0            NaN              NaN
# BO 1 load                0.0            NaN              NaN
# BO 2 load                0.0            NaN              NaN
# BO 3 load                0.0            NaN              NaN
# BO 4 load                0.0            NaN              NaN
# BO 5 load                0.0            NaN              NaN
# BO 6 load                0.0            NaN              NaN
# BO 7 load                0.0            NaN              NaN
# BO 8 load                0.0            NaN              NaN
# BO 9 load                0.0            NaN              NaN
#
#               ramp_limit_start_up  ramp_limit_shut_down
# Generator
# BO 0 OCGT                     1.0                   1.0
# BO 0 biomass                  1.0                   1.0
# BO 0 onwind                   1.0                   1.0
# BO 0 solar                    1.0                   1.0
# BO 1 onwind                   1.0                   1.0
# BO 1 solar                    1.0                   1.0
# BO 2 OCGT                     1.0                   1.0
# BO 2 oil                      1.0                   1.0
# BO 2 onwind                   1.0                   1.0
# BO 2 solar                    1.0                   1.0
# BO 3 OCGT                     1.0                   1.0
# BO 3 onwind                   1.0                   1.0
# BO 3 ror                      1.0                   1.0
# BO 3 solar                    1.0                   1.0
# BO 4 biomass                  1.0                   1.0
# BO 4 oil                      1.0                   1.0
# BO 4 onwind                   1.0                   1.0
# BO 4 solar                    1.0                   1.0
# BO 5 OCGT                     1.0                   1.0
# BO 5 onwind                   1.0                   1.0
# BO 5 solar                    1.0                   1.0
# BO 6 OCGT                     1.0                   1.0
# BO 6 onwind                   1.0                   1.0
# BO 6 solar                    1.0                   1.0
# BO 7 onwind                   1.0                   1.0
# BO 7 ror                      1.0                   1.0
# BO 7 solar                    1.0                   1.0
# BO 8 onwind                   1.0                   1.0
# BO 8 solar                    1.0                   1.0
# BO 9 onwind                   1.0                   1.0
# BO 9 solar                    1.0                   1.0
# BO 0 load                     1.0                   1.0
# BO 1 load                     1.0                   1.0
# BO 2 load                     1.0                   1.0
# BO 3 load                     1.0                   1.0
# BO 4 load                     1.0                   1.0
# BO 5 load                     1.0                   1.0
# BO 6 load                     1.0                   1.0
# BO 7 load                     1.0                   1.0
# BO 8 load                     1.0                   1.0
# BO 9 load                     1.0                   1.0

# %%
#Imprimir la suma de potencias nominales (2013) de los generadores de Bolivia

####### Data was not yet updated and therefore a big difference between real capacities in 2020 (largely oversized) and optimized installed capacities (relatively low changes)
# - To change this, additional plants have to be added to better represent the system

idx = ['BO' in x for x in n.generators.index]
n.generators.loc[idx,:].p_nom.sum()
# Out:
# 10000001526.468107

# %%
# Difference between total load and generation
# losses = n.stores_t

n.generators_t.p.sum().sum() - n.loads_t.p.sum().sum()  # - substract storage losses
# Out:
# 156459102.36640614

# %% [markdown]
# ### Total installed generator capacity

# %%
gen_cap = n.generators.groupby(["carrier"]).sum()
gen_cap
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_27344\2958603594.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gen_cap = n.generators.groupby(["carrier"]).sum()
#             p_nom_max         weight         p_nom  capital_cost  efficiency  \
# carrier
# OCGT              NaN       0.000000  9.143409e+02  2.361728e+05       1.950
# biomass           NaN       0.000000  7.723000e+01  5.560307e+05       0.936
# load              NaN       0.000000  1.000000e+10  0.000000e+00      10.000
# oil               NaN       0.000000  4.573651e+01  7.646912e+04       0.786
# onwind   2.376047e+06  124486.370505  2.596471e+01  1.092956e+06      10.000
# ror               NaN     344.006279  3.440063e+02  5.418814e+05       1.800
# solar    1.869632e+06  324318.258522  1.191897e+02  5.085596e+05      10.000
#
#           p_nom_min  marginal_cost  p_nom_extendable     p_nom_opt   sign  \
# carrier
# OCGT     914.340881     291.969349                 5  9.143805e+02   5.00
# biomass   77.230000      29.934547                 0  7.723000e+01   2.00
# load       0.000000      10.102498                 0  1.000000e+10   0.01
# oil       45.736513     260.473081                 0  4.573651e+01   2.00
# onwind    25.964709       0.252814                 0  2.596471e+01  10.00
# ror        0.000000       0.019754                 0  3.440063e+02   2.00
# solar    119.189726       0.195833                 0  1.191897e+02  10.00
#
#          build_year  min_up_time  min_down_time  up_time_before  \
# carrier
# OCGT              0            0              0               5
# biomass           0            0              0               2
# load              0            0              0              10
# oil               0            0              0               2
# onwind            0            0              0              10
# ror               0            0              0               2
# solar             0            0              0              10
#
#          down_time_before  p_min_pu  p_max_pu  p_set  q_set  lifetime  \
# carrier
# OCGT                    0       0.0       5.0    0.0    0.0       NaN
# biomass                 0       0.0       2.0    0.0    0.0       NaN
# load                    0       0.0      10.0    0.0    0.0       NaN
# oil                     0       0.0       2.0    0.0    0.0       NaN
# onwind                  0       0.0      10.0    0.0    0.0       NaN
# ror                     0       0.0       2.0    0.0    0.0       NaN
# solar                   0       0.0      10.0    0.0    0.0       NaN
#
#          committable  start_up_cost  shut_down_cost  ramp_limit_up  \
# carrier
# OCGT               0            0.0             0.0            0.0
# biomass            0            0.0             0.0            0.0
# load               0            0.0             0.0            0.0
# oil                0            0.0             0.0            0.0
# onwind             0            0.0             0.0            0.0
# ror                0            0.0             0.0            0.0
# solar              0            0.0             0.0            0.0
#
#          ramp_limit_down  ramp_limit_start_up  ramp_limit_shut_down
# carrier
# OCGT                 0.0                  5.0                   5.0
# biomass              0.0                  2.0                   2.0
# load                 0.0                 10.0                  10.0
# oil                  0.0                  2.0                   2.0
# onwind               0.0                 10.0                  10.0
# ror                  0.0                  2.0                   2.0
# solar                0.0                 10.0                  10.0

# %%
n.stores_t.p.head()
# Out:
# Store                 BO 0 H2   BO 1 H2   BO 2 H2   BO 3 H2   BO 4 H2  \
# snapshot
# 2013-01-01 00:00:00  0.003876  0.004059  0.004007  0.004238  0.000015
# 2013-01-01 06:00:00 -0.003982 -0.004318 -0.003698 -0.004445 -0.000038
# 2013-01-01 12:00:00  0.007236  0.007330  0.006605  0.007422 -0.000013
# 2013-01-01 18:00:00 -0.008948 -0.008575 -0.009168 -0.008584 -0.000004
# 2013-01-02 00:00:00  0.003635  0.003798  0.004141  0.003591 -0.000040
#
# Store                 BO 5 H2   BO 6 H2   BO 7 H2   BO 8 H2       BO 9 H2  \
# snapshot
# 2013-01-01 00:00:00  0.003796  0.004116  0.004043 -0.000011 -1.190099e-07
# 2013-01-01 06:00:00 -0.004554 -0.003863 -0.003968 -0.000011 -6.593688e-06
# 2013-01-01 12:00:00  0.008029  0.007179  0.006886  0.000011  4.416415e-06
# 2013-01-01 18:00:00 -0.008828 -0.008909 -0.008863  0.000012  4.279037e-06
# 2013-01-02 00:00:00  0.003362  0.003776  0.003972 -0.000010 -3.284223e-07
#
# Store                BO 0 battery  BO 1 battery  BO 2 battery  BO 3 battery  \
# snapshot
# 2013-01-01 00:00:00      0.000209      0.000304      0.000271      0.000332
# 2013-01-01 06:00:00     -0.000599     -0.000725     -0.000514     -0.000744
# 2013-01-01 12:00:00      0.000538      0.000588      0.000464      0.000589
# 2013-01-01 18:00:00     -0.000086     -0.000047     -0.000257     -0.000023
# 2013-01-02 00:00:00      0.000177      0.000160      0.000352      0.000129
#
# Store                BO 4 battery  BO 5 battery  BO 6 battery  BO 7 battery  \
# snapshot
# 2013-01-01 00:00:00      0.000033      0.000219      0.000258      0.000267
# 2013-01-01 06:00:00     -0.000210     -0.000701     -0.000623     -0.000661
# 2013-01-01 12:00:00     -0.000006      0.000593      0.000543      0.000557
# 2013-01-01 18:00:00      0.000040     -0.000002     -0.000080     -0.000061
# 2013-01-02 00:00:00     -0.000092      0.000100      0.000172      0.000160
#
# Store                BO 8 battery  BO 9 battery
# snapshot
# 2013-01-01 00:00:00     -0.000047     -0.000013
# 2013-01-01 06:00:00     -0.000053     -0.000081
# 2013-01-01 12:00:00      0.000042      0.000037
# 2013-01-01 18:00:00      0.000054      0.000038
# 2013-01-02 00:00:00     -0.000046     -0.000003

# %%
n.generators_t.p_max_pu.groupby(n.generators.carrier, axis=1).mean().plot()
# Out:
# <AxesSubplot:xlabel='snapshot'>

# %%
# If 0, all renewable capacity potential is used
n.generators.p_nom_max.sum() - n.generators.p_nom_opt.sum()
# Out:
# inf

# %%
n.loads_t.p.sum().sum()
# Out:
# 802471.0199702531

# %%
n.generators_t.p.sum().sum()
# Out:
# 157261573.38637638

# %%
#### pq la multiplicacion?

n.generators.iloc[:, :].groupby(["bus", "carrier"]).p_nom.sum() * 0.0000003
# Out:
# bus   carrier
# BO 0  OCGT       1.060691e-04
#       biomass    2.168700e-05
#       load       3.000000e+02
#       onwind     3.656775e-06
#       solar      3.380796e-06
# BO 1  load       3.000000e+02
#       onwind     3.121608e-07
#       solar      6.799367e-06
# BO 2  OCGT       3.622322e-05
#       load       3.000000e+02
#       oil        1.019895e-05
#       onwind     1.953577e-06
#       solar      1.502944e-05
# BO 3  OCGT       2.167464e-05
#       load       3.000000e+02
#       onwind     6.559479e-08
#       ror        7.821645e-05
#       solar      3.271149e-06
# BO 4  biomass    1.482000e-06
#       load       3.000000e+02
#       oil        3.522000e-06
#       onwind     1.681481e-06
#       solar      5.814411e-06
# BO 5  OCGT       4.495021e-05
#       load       3.000000e+02
#       onwind     0.000000e+00
#       solar      3.880421e-07
# BO 6  OCGT       6.538507e-05
#       load       3.000000e+02
#       onwind     7.859891e-08
#       solar      2.834468e-07
# BO 7  load       3.000000e+02
#       onwind     4.122531e-08
#       ror        2.498544e-05
#       solar      6.673308e-07
# BO 8  load       3.000000e+02
#       onwind     0.000000e+00
#       solar      1.229392e-07
# BO 9  load       3.000000e+02
#       onwind     0.000000e+00
#       solar      0.000000e+00
# Name: p_nom, dtype: float64

# %%
fig, ax = plt.subplots(
    figsize=(10, 10),
    subplot_kw={
        "projection": ccrs.PlateCarree()
    },  # PlateCarree(default), Mercator, Orthographic
)

# loading = (n3.lines_t.p0.abs().mean().sort_index() / (n3.lines.s_nom_opt*n.lines.s_max_pu).sort_index()).fillna(0.)

n.plot(
    margin=0.1,
    ax=None,
    geomap=True,  #'10m' leads to a beautiful high resolution map
    projection=None,
    bus_colors="cadetblue",
    bus_alpha=1,
    bus_sizes=normalize_node_size(
        n.generators.iloc[:, :].groupby(["bus", "carrier"]).p_nom_opt.sum()),
    bus_cmap=None,
    line_colors="rosybrown",
    link_colors="darkseagreen",  # loading
    transformer_colors="orange",
    line_widths=n.lines.s_nom_opt / 3e2,
    link_widths=1.5,
    transformer_widths=1.5,
    line_cmap=None,
    link_cmap=None,  # plt.cm.virdis (colordmap for line loading)
    transformer_cmap=None,
    flow=None,
    branch_components=None,
    layouter=None,
    title="Generator Map",
    boundaries=None,
    geometry=False,
    jitter=None,
    color_geomap=True,
)  # None or True

ax.axis("off");
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[22], line 10
#       1 fig, ax = plt.subplots(
#       2     figsize=(10, 10),
#       3     subplot_kw={
#       4         "projection": ccrs.PlateCarree()
#       5     },  # PlateCarree(default), Mercator, Orthographic
#       6 )
#       8 # loading = (n3.lines_t.p0.abs().mean().sort_index() / (n3.lines.s_nom_opt*n.lines.s_max_pu).sort_index()).fillna(0.)
# ---> 10 n.plot(
#      11     margin=0.1,
#      12     ax=None,
#      13     geomap=True,  #'10m' leads to a beautiful high resolution map
#      14     projection=None,
#      15     bus_colors="cadetblue",
#      16     bus_alpha=1,
#      17     bus_sizes=normalize_node_size(
#      18         n.generators.iloc[:, :].groupby(["bus", "carrier"]).p_nom_opt.sum()),
#      19     bus_cmap=None,
#      20     line_colors="rosybrown",
#      21     link_colors="darkseagreen",  # loading
#      22     transformer_colors="orange",
#      23     line_widths=n.lines.s_nom_opt / 3e2,
#      24     link_widths=1.5,
#      25     transformer_widths=1.5,
#      26     line_cmap=None,
#      27     link_cmap=None,  # plt.cm.virdis (colordmap for line loading)
#      28     transformer_cmap=None,
#      29     flow=None,
#      30     branch_components=None,
#      31     layouter=None,
#      32     title="Generator Map",
#      33     boundaries=None,
#      34     geometry=False,
#      35     jitter=None,
#      36     color_geomap=True,
#      37 )  # None or True
#      39 ax.axis("off");
#
# File c:\Users\Lenovo\anaconda3\envs\pypsa-earth\lib\site-packages\pypsa\plot.py:249, in plot(n, margin, ax, geomap, projection, bus_colors, bus_alpha, bus_sizes, bus_cmap, bus_norm, line_colors, link_colors, transformer_colors, line_alpha, link_alpha, transformer_alpha, line_widths, link_widths, transformer_widths, line_cmap, link_cmap, transformer_cmap, line_norm, link_norm, transformer_norm, flow, branch_components, layouter, title, boundaries, geometry, jitter, color_geomap)
#     247 if not isinstance(bus_colors, pd.Series):
#     248     bus_colors = n.carriers.color.dropna()
# --> 249 assert bus_sizes.index.levels[1].isin(bus_colors.index).all(), (
#     250     "Colors not defined for all elements in the second MultiIndex "
#     251     "level of bus_sizes, please make sure that all the elements are "
#     252     "included in bus_colors or in n.carriers.color"
#     253 )
#     255 bus_sizes = bus_sizes.sort_index(level=0, sort_remaining=False)
#     256 if geomap:
#
# AssertionError: Colors not defined for all elements in the second MultiIndex level of bus_sizes, please make sure that all the elements are included in bus_colors or in n.carriers.color

# %% [markdown]
# ### Demand

# %%
print(type(n.generators.iloc[:, :].groupby(["bus"]).p_nom_opt.sum()))

print(n.generators.iloc[:, :].groupby(["bus"]).p_nom_opt.sum())
# Out:
# <class 'pandas.core.series.Series'>
# bus
# BO 0    1.000000e+09
# BO 1    1.000000e+09
# BO 2    1.000000e+09
# BO 3    1.000000e+09
# BO 4    1.000003e+09
# BO 5    1.000000e+09
# BO 6    1.000002e+09
# BO 7    1.000000e+09
# BO 8    1.000000e+09
# BO 9    1.000000e+09
# Name: p_nom_opt, dtype: float64

# %%
n.loads_t.p_set.loc["2013-01-01":"2013-06-06","BO 0"].plot()
# Out:
# <AxesSubplot:xlabel='snapshot'>

# %%
type(n.loads_t.p_set.sum())
# Out:
# pandas.core.series.Series

# %%
a = n.loads_t.p_set.sum().rename("load").rename_axis("bus")
a.rename("load", inplace=True)
a.rename_axis("bus", inplace=True)
a
# Out:
# bus
# BO 0    165760.688502
# BO 1     81159.348527
# BO 2    191724.571497
# BO 3     66017.013065
# BO 4    149443.435993
# BO 5     48288.153868
# BO 6     73000.693259
# BO 7      1794.942286
# BO 8     18036.350625
# BO 9      7245.822349
# Name: load, dtype: float64

# %%
n.generators.iloc[:, :].groupby(["bus"]).p_nom_opt.sum()

###### potencia maxima?
#n.generators.iloc[:, :].groupby(["bus"]).p_max_pu.sum()
# Out:
# bus
# BO 0    1.000000e+09
# BO 1    1.000000e+09
# BO 2    1.000000e+09
# BO 3    1.000000e+09
# BO 4    1.000003e+09
# BO 5    1.000000e+09
# BO 6    1.000002e+09
# BO 7    1.000000e+09
# BO 8    1.000000e+09
# BO 9    1.000000e+09
# Name: p_nom_opt, dtype: float64

# %%
fig, ax = plt.subplots(
    figsize=(10, 10),
    subplot_kw={
        "projection": ccrs.PlateCarree()
    },  # PlateCarree(default), Mercator, Orthographic
)

# loading = (n3.lines_t.p0.abs().mean().sort_index() / (n3.lines.s_nom_opt*n.lines.s_max_pu).sort_index()).fillna(0.)

n.plot(
    margin=0.1,
    ax=None,
    geomap=True,  #'10m' leads to a beautiful high resolution map
    projection=None,
    bus_colors="cadetblue",
    bus_alpha=1,
    bus_sizes=normalize_node_size(
        n.loads_t.p_set.sum().rename("load").rename_axis("bus")
    ),  # n.loads_t.p_set.sum().rename("load").rename_axis("bus")*.0000003,
    bus_cmap=None,
    line_colors="rosybrown",
    link_colors="darkseagreen",  # loading
    transformer_colors="orange",
    line_widths=n.lines.s_nom_opt / 3000000000e2,
    link_widths=1.5,
    transformer_widths=1.5,
    line_cmap=None,
    link_cmap=None,  # plt.cm.virdis (colordmap for line loading)
    transformer_cmap=None,
    flow=None,
    branch_components=None,
    layouter=None,
    title="Generator Map",
    boundaries=None,
    geometry=False,
    jitter=None,
    color_geomap=True,
)  # None or True

ax.axis("off");

# %%
# backup
gen_serie = n.generators.iloc[:, :].groupby(["bus", "carrier"]).p_nom_opt.sum()
load_serie = n.loads_t.p_set.sum().rename("load").rename_axis("bus")

load_serie = pd.Series(
    load_serie.values,
    index=pd.MultiIndex.from_tuples([(id, "AC load") for id in load_serie.index]),
)

tot_serie = pd.concat([gen_serie, load_serie])  # .groupby(['bus', 'carrier']).sum()

pd.concat([gen_serie, load_serie])
# Out:
# bus   carrier
# BO 0  OCGT       3.535640e+02
#       load       1.000000e+09
#       onwind     1.218930e+01
#       solar      1.126941e+01
# BO 1  OCGT       7.224898e+01
#       load       1.000000e+09
#       onwind     2.186599e-01
#       ror        2.607215e+02
#       solar      1.090423e+01
# BO 2  OCGT       1.078072e+02
#       load       1.000000e+09
#       oil        3.399651e+01
#       onwind     6.511956e+00
#       solar      4.635814e+01
# BO 3  OCGT       1.498342e+02
#       load       1.000000e+09
#       onwind     3.850991e-05
#       ror        8.328479e+01
#       solar      3.159106e+00
# BO 4  load       1.000000e+09
#       onwind     5.604957e+00
#       solar      3.059832e+03
# BO 5  OCGT       2.179503e+02
#       load       1.000000e+09
#       onwind     3.995894e-01
#       solar      1.303728e+00
# BO 6  load       1.000000e+09
#       onwind     1.040557e+00
#       solar      1.637178e+03
# BO 7  load       1.000000e+09
#       onwind     6.234531e-05
#       solar      2.688550e+01
# BO 8  load       1.000000e+09
#       onwind     2.520803e-06
#       solar      4.563136e+02
# BO 9  OCGT       1.293689e+01
#       load       1.000000e+09
#       onwind     1.198507e-04
#       solar      3.742515e+00
# BO 0  AC load    1.657607e+05
# BO 1  AC load    8.115935e+04
# BO 2  AC load    1.917246e+05
# BO 3  AC load    6.601701e+04
# BO 4  AC load    1.494434e+05
# BO 5  AC load    4.828815e+04
# BO 6  AC load    7.300069e+04
# BO 7  AC load    1.794942e+03
# BO 8  AC load    1.803635e+04
# BO 9  AC load    7.245822e+03
# dtype: float64

# %% [markdown]
# ### Plot of Average Marginal Price

# %%
now = n.snapshots[4]  ##one specific time

fig, ax = plt.subplots(1, 1, subplot_kw={"projection": ccrs.PlateCarree()})
fig.set_size_inches(6, 4)

n.plot(ax=ax, line_widths=pd.Series(0.5, n.lines.index))
plt.hexbin(
    n.buses.x,
    n.buses.y,
    gridsize=20,
    # C=n.buses_t.marginal_price.loc[now], #at one time (previous set up by scigrid)
    C=n.buses_t.marginal_price.sum()
    / len(n.snapshots[:]),  # Marginal price averaged over the whole year (My version)
    # - shows in which regions electricity will be cheap and where el. intensive companies should be placed.
    cmap=plt.cm.jet,
)

# for some reason the colorbar only works with graphs plt.plot
# and must be attached plt.colorbar

cb = plt.colorbar()
cb.set_label("Locational Marginal Price (EUR/MWh)")

# %% [markdown]
# ### Storage

# %%
n.stores_t.e.loc["2013-01-01":"2013-06-01"].sum(axis=1).plot()
# Out:
# <AxesSubplot:xlabel='snapshot'>

# %%
n.links.iloc[:].groupby(["carrier"]).p_nom_opt.sum()
# Out:
# carrier
# H2 electrolysis       779.227504
# H2 fuel cell          482.534463
# battery charger         0.017229
# battery discharger      0.019144
# Name: p_nom_opt, dtype: float64
