# %%
###### algunas cosas cambian si pongo como comentarios en el import de geoviews y hvplot (liberias conflictivas?)

import logging
import os

import pypsa
import yaml
import pandas as pd
import geopandas as gpd
#import geoviews as gv
#import hvplot.pandas 
import numpy as np
import scipy as sp
import networkx as nx

# plotting stuff
import matplotlib.pyplot as plt

plt.style.use("bmh")
import seaborn as sns  ###
import cartopy.crs as ccrs

sns.set(style="darkgrid")

from scipy.sparse import csgraph
from itertools import product

from shapely.geometry import Point, LineString
import shapely, shapely.prepared, shapely.wkt

logger = logging.getLogger(__name__)

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 70)

import sys

sys.path.append("../")  # to import helpers
from scripts._helpers import sets_path_to_root

sets_path_to_root("pypsa-earth")

max_node_size = 1.0  # maximum size of a node for plotting purposes [used in plots]
# Out:
# This is the repository path:  /Users/adelehannotte/Pypsa-earth/pypsa-earth
# Had to go 1 folder(s) up.

# %%
# utility function for nice plotting


def normalize_node_size(values, max_node_size=max_node_size):
    return values / values.max() * max_node_size

# %%
world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
shapes=world[world.name.isin(["Bolivia"])].set_index("name")

# %% [markdown]
# ## 4 buses clustering

# %%
solved_4_network = os.getcwd() +  "/results/networks/elec_s_4_ec_lcopt_Co2L-3H.nc"

#Se cargan los resultados de la optimizacion del problema segun las caracteristicas definidas para el modelo en n_solve con la funcion (operador?) Network de pypsa

n_solve_4 = pypsa.Network(solved_4_network)
# Out:
# INFO:pypsa.io:Imported network elec_s_4_ec_lcopt_Co2L-3H.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n_solve_4.objective
# Out:
# nan

# %%
fig, ax = plt.subplots(figsize=(7, 7),subplot_kw={'projection': ccrs.PlateCarree()})

n_solve_4.plot(ax=ax)
ax.set_extent([shapes.total_bounds[0], shapes.total_bounds[2],shapes.total_bounds[1], shapes.total_bounds[3]], crs=ccrs.PlateCarree())
# Out:
# /opt/anaconda3/envs/pypsa-earth/lib/python3.10/site-packages/cartopy/mpl/style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# ## 10 buses clustering

# %%
solved_10_network = os.getcwd() +  "/results/networks/elec_s_10_ec_lcopt_Co2L-3H.nc"

#Se cargan los resultados de la optimizacion del problema segun las caracteristicas definidas para el modelo en n_solve con la funcion (operador?) Network de pypsa

n_solve_10 = pypsa.Network(solved_10_network)

fig, ax = plt.subplots(figsize=(7, 7),subplot_kw={'projection': ccrs.PlateCarree()})

n_solve_10.plot(ax=ax)
ax.set_extent([shapes.total_bounds[0], shapes.total_bounds[2],shapes.total_bounds[1], shapes.total_bounds[3]], crs=ccrs.PlateCarree())
# Out:
# INFO:pypsa.io:Imported network elec_s_10_ec_lcopt_Co2L-3H.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores
# /opt/anaconda3/envs/pypsa-earth/lib/python3.10/site-packages/cartopy/mpl/style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# ## 20 buses clustering

# %%
solved_20_network = os.getcwd() +  "/results/networks/elec_s_20_ec_lcopt_Co2L-3H.nc"

#Se cargan los resultados de la optimizacion del problema segun las caracteristicas definidas para el modelo en n_solve con la funcion (operador?) Network de pypsa

n_solve_20 = pypsa.Network(solved_20_network)

fig, ax = plt.subplots(figsize=(7, 7),subplot_kw={'projection': ccrs.PlateCarree()})

n_solve_20.plot(ax=ax)
ax.set_extent([shapes.total_bounds[0], shapes.total_bounds[2],shapes.total_bounds[1], shapes.total_bounds[3]], crs=ccrs.PlateCarree())
# Out:
# INFO:pypsa.io:Imported network elec_s_20_ec_lcopt_Co2L-3H.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores
# /opt/anaconda3/envs/pypsa-earth/lib/python3.10/site-packages/cartopy/mpl/style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# ## 35 buses clustering

# %%
solved_35_network = os.getcwd() +  "/results/networks/elec_s_35_ec_lcopt_Co2L-3H.nc"

#Se cargan los resultados de la optimizacion del problema segun las caracteristicas definidas para el modelo en n_solve con la funcion (operador?) Network de pypsa

n_solve_35 = pypsa.Network(solved_35_network)

fig, ax = plt.subplots(figsize=(7, 7),subplot_kw={'projection': ccrs.PlateCarree()})

n_solve_35.plot(ax=ax)
ax.set_extent([shapes.total_bounds[0], shapes.total_bounds[2],shapes.total_bounds[1], shapes.total_bounds[3]], crs=ccrs.PlateCarree())
# Out:
# INFO:pypsa.io:Imported network elec_s_35_ec_lcopt_Co2L-3H.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores
# /opt/anaconda3/envs/pypsa-earth/lib/python3.10/site-packages/cartopy/mpl/style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# ## 37 buses clustering

# %%
solved_37_network = os.getcwd() +  "/results/networks/elec_s_37_ec_lcopt_Co2L-3H.nc"

#Se cargan los resultados de la optimizacion del problema segun las caracteristicas definidas para el modelo en n_solve con la funcion (operador?) Network de pypsa

n_solve_37 = pypsa.Network(solved_37_network)

fig, ax = plt.subplots(figsize=(7, 7),subplot_kw={'projection': ccrs.PlateCarree()})

n_solve_37.plot(ax=ax)
ax.set_extent([shapes.total_bounds[0], shapes.total_bounds[2],shapes.total_bounds[1], shapes.total_bounds[3]], crs=ccrs.PlateCarree())
# Out:
# INFO:pypsa.io:Imported network elec_s_37_ec_lcopt_Co2L-3H.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores
# /opt/anaconda3/envs/pypsa-earth/lib/python3.10/site-packages/cartopy/mpl/style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %%
n_solve_37.objective
# Out:
# 546064692.6938337

# %% [markdown]
# ## Base network

# %%
base_network= os.getcwd() +  "/networks/base.nc"

n_base= pypsa.Network(base_network)
# Out:
# INFO:pypsa.io:Imported network base.nc has buses, lines, transformers

# %%
n_base
# Out:
# PyPSA Network 'PyPSA-Eur'
# Components:
#  - Bus: 131
#  - Line: 115
#  - Transformer: 19
# Snapshots: 8760

# %%
fig, ax = plt.subplots(figsize=(7, 7),subplot_kw={'projection': ccrs.PlateCarree()})

n_base.plot(ax=ax)
ax.set_extent([shapes.total_bounds[0], shapes.total_bounds[2],shapes.total_bounds[1], shapes.total_bounds[3]], crs=ccrs.PlateCarree())
# Out:
# /opt/anaconda3/envs/pypsa-earth/lib/python3.10/site-packages/cartopy/mpl/style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %%
n_base.plot()
# Out:
# (<matplotlib.collections.PatchCollection at 0x16ff09fc0>,
#  <matplotlib.collections.LineCollection at 0x16fe85810>,
#  <matplotlib.collections.LineCollection at 0x16fe856c0>)
# /opt/anaconda3/envs/pypsa-earth/lib/python3.10/site-packages/cartopy/mpl/style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# # Comparison with real bolivian network

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import matplotlib as mpl

mpl.rcParams['figure.dpi']= 300
#mpl.rc("figure", dpi=200)
plt.grid(None) 
plt.axis('off')
plt.imshow(mpimg.imread(os.getcwd() +  "/post_process/network_maps/Red_2012.png"))
plt.show()

# %% [markdown]
# Network map for 2012
#
# source: https://geo.gob.bo/mapfishapp/
#
# (Red electrica)
#
# en tres categorías de distinto color rojo 69, azul 115 y verde 230 en KV

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import matplotlib as mpl

mpl.rcParams['figure.dpi']= 300
#mpl.rc("figure", dpi=200)
plt.grid(None) 
plt.axis('off')
plt.imshow(mpimg.imread(os.getcwd() +  "/post_process/network_maps/network_2025.png"))
plt.show()

# %% [markdown]
# Network map for 2025
#
# https://observatorioccdbolivia.files.wordpress.com/2015/08/peebol2025.pdf

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import matplotlib as mpl

mpl.rcParams['figure.dpi']= 300
#mpl.rc("figure", dpi=200)
plt.grid(None) 
plt.axis('off')
plt.imshow(mpimg.imread(os.getcwd() +  "/post_process/network_maps/network_2022.png"))
plt.show()

# %% [markdown]
# Network map for 2022
#
# https://observatorioccdbolivia.files.wordpress.com/2015/08/plan-de-expansic3b3n-del-sin-2012-2022.pdf

# %%
import matplotlib.pyplot as plt
import pypsa
import numpy as np
import cartopy.crs as ccrs

#determine the limits of the country
world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
shapes=world[world.name.isin(["Bolivia"])].set_index("name")

# create a subplot with 1 row and 2 columns
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5),subplot_kw={'projection': ccrs.PlateCarree()})
#fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# plot your network in the first subplot
n_base.plot(ax=ax1)
ax1.set_extent([shapes.total_bounds[0], shapes.total_bounds[2],shapes.total_bounds[1], shapes.total_bounds[3]], crs=ccrs.PlateCarree())

# hide the background map
#ax1.background_patch.set_visible(False)

# show an image in the second subplot
img = plt.imread(os.getcwd() +  "/post_process/network_maps/Red_2012.png")
extent = (0, img.shape[1]*0.1, 0, img.shape[0]*0.1) # left, right, bottom, top
ax2.imshow(img, extent=extent)

# optionally, add titles to your subplots
ax1.set_title('Base network Plot')
ax2.set_title('Network Map for 2012 (Red)')

# show the subplots
plt.show()
# Out:
# /opt/anaconda3/envs/pypsa-earth/lib/python3.10/site-packages/cartopy/mpl/style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# en tres categorías de distinto color rojo 69, azul 115 y verde 230 en KV

# %%
import matplotlib.pyplot as plt
import pypsa
import numpy as np
import cartopy.crs as ccrs

#determine the limits of the country
world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
shapes=world[world.name.isin(["Bolivia"])].set_index("name")

# create a subplot with 1 row and 2 columns
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5),subplot_kw={'projection': ccrs.PlateCarree()})
#fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# plot your network in the first subplot
n_solve_35.plot(ax=ax1,margin=0.5)
ax1.set_extent([shapes.total_bounds[0], shapes.total_bounds[2],shapes.total_bounds[1], shapes.total_bounds[3]], crs=ccrs.PlateCarree())

# hide the background map
#ax1.background_patch.set_visible(False)

# show an image in the second subplot
img = plt.imread(os.getcwd() +  "/post_process/network_maps/Red_2012.png")
extent = (0, img.shape[1]*0.1, 0, img.shape[0]*0.1) # left, right, bottom, top
ax2.imshow(img, extent=extent)

# optionally, add titles to your subplots
ax1.set_title('Clustered (35 buses) network Plot')
ax2.set_title('Network Map for 2012 (Red)')

# show the subplots
plt.show()
# Out:
# /opt/anaconda3/envs/pypsa-earth/lib/python3.10/site-packages/cartopy/mpl/style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# ## Check why there is a limit

# %% [markdown]
# When I try whith 38 or more:
#
# ERROR:__main__:Desired number of clusters (38) higher than the number of buses (37)
#
# Error in rule cluster_network:
#     jobid: 4
#     input: networks/elec_s.nc, resources/shapes/country_shapes.geojson, resources/bus_regions/regions_onshore_elec_s.geojson, resources/bus_regions/regions_offshore_elec_s.geojson, resources/shapes/gadm_shapes.geojson, data/costs.csv
#     output: networks/elec_s_39.nc, resources/bus_regions/regions_onshore_elec_s_39.geojson, resources/bus_regions/regions_offshore_elec_s_39.geojson, resources/bus_regions/busmap_elec_s_39.csv, resources/bus_regions/linemap_elec_s_39.csv
#     log: logs/cluster_network/elec_s_39.log (check log file(s) for error details)

# %% [markdown]
# MAYBE because the simplify_network function is limitng the line voltage with a minimum of 380 kV so the minor lines are not taking into acount

# %%
n_solve_35
# Out:
# PyPSA Network
# Components:
#  - Bus: 105
#  - Carrier: 16
#  - Generator: 116
#  - GlobalConstraint: 1
#  - Line: 36
#  - Link: 140
#  - Load: 35
#  - StorageUnit: 2
#  - Store: 70
# Snapshots: 2920

# %%
n_base
# Out:
# PyPSA Network 'PyPSA-Eur'
# Components:
#  - Bus: 131
#  - Line: 115
#  - Transformer: 19
# Snapshots: 8760

# %% [markdown]
# ## Check why there is no objective (if solve is working)

# %% [markdown]
# Thought it come from the solve function since the /networks files have no objective (is it right) and the /solutions have one.
#
# /solutions files are output of the solve_network function
# /networks are input

# %%
cluster_network = os.getcwd() +  "/networks/elec_s_35.nc"

#Se cargan los resultados de la optimizacion del problema segun las caracteristicas definidas para el modelo en n_solve con la funcion (operador?) Network de pypsa

n_cluster = pypsa.Network(cluster_network)

n_cluster
# Out:
# INFO:pypsa.io:Imported network elec_s_35.nc has buses, carriers, generators, lines, loads, storage_units
# PyPSA Network
# Components:
#  - Bus: 35
#  - Carrier: 13
#  - Generator: 81
#  - Line: 36
#  - Load: 35
#  - StorageUnit: 2
# Snapshots: 8760

# %%
cluster_ec_network = os.getcwd() +  "/networks/elec_s_35_ec.nc"

#Se cargan los resultados de la optimizacion del problema segun las caracteristicas definidas para el modelo en n_solve con la funcion (operador?) Network de pypsa

n_cluster_ec = pypsa.Network(cluster_ec_network)

n_cluster_ec
# Out:
# INFO:pypsa.io:Imported network elec_s_35_ec.nc has buses, carriers, generators, lines, links, loads, storage_units, stores
# PyPSA Network
# Components:
#  - Bus: 105
#  - Carrier: 15
#  - Generator: 81
#  - Line: 36
#  - Link: 140
#  - Load: 35
#  - StorageUnit: 2
#  - Store: 70
# Snapshots: 8760

# %%
opt_network = os.getcwd() +  "/networks/elec_s_35_ec_lcopt_Co2L-3H.nc"

#Se cargan los resultados de la optimizacion del problema segun las caracteristicas definidas para el modelo en n_solve con la funcion (operador?) Network de pypsa

n_opt = pypsa.Network(opt_network)

n_opt
# Out:
# INFO:pypsa.io:Imported network elec_s_35_ec_lcopt_Co2L-3H.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores
# PyPSA Network
# Components:
#  - Bus: 105
#  - Carrier: 15
#  - Generator: 81
#  - GlobalConstraint: 1
#  - Line: 36
#  - Link: 140
#  - Load: 35
#  - StorageUnit: 2
#  - Store: 70
# Snapshots: 2920

# %%
n_solve_35
# Out:
# PyPSA Network
# Components:
#  - Bus: 105
#  - Carrier: 16
#  - Generator: 116
#  - GlobalConstraint: 1
#  - Line: 36
#  - Link: 140
#  - Load: 35
#  - StorageUnit: 2
#  - Store: 70
# Snapshots: 2920

# %%
n_solve_35.plot()
# Out:
# (<matplotlib.collections.PatchCollection at 0x173e9dc30>,
#  <matplotlib.collections.LineCollection at 0x1745b06d0>,
#  <matplotlib.collections.LineCollection at 0x1745b0580>)
# /opt/anaconda3/envs/pypsa-earth/lib/python3.10/site-packages/cartopy/mpl/style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %%
n_cluster.plot()
# Out:
# (<matplotlib.collections.PatchCollection at 0x173f1f280>,
#  <matplotlib.collections.LineCollection at 0x173f014e0>)
# /opt/anaconda3/envs/pypsa-earth/lib/python3.10/site-packages/cartopy/mpl/style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# ## Making nice graphs

# %%
import matplotlib.pyplot as plt
import pypsa
import numpy as np
import cartopy.crs as ccrs

countries = ["Bolivia"]
world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
shapes=world[world.name.isin(countries)].set_index("name")
shapes

# Plotting requirements
xlim = [shapes.total_bounds[0], shapes.total_bounds[2]]
ylim = [shapes.total_bounds[1], shapes.total_bounds[3]]
ax.set_xlim(xlim)
ax.set_ylim(ylim)

ylim
# Out:
# [-22.872918796482175, -9.761987806846392]

# %%
import matplotlib.pyplot as plt
import pypsa
import numpy as np
import cartopy.crs as ccrs

#countries = ["Bolivia"]

world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
shapes=world[world.name.isin(["Bolivia"])].set_index("name")
fig, ax = plt.subplots(figsize=(7, 7),subplot_kw={'projection': ccrs.PlateCarree()})

n_solve_10.plot(ax=ax)
ax.set_extent([shapes.total_bounds[0], shapes.total_bounds[2],shapes.total_bounds[1], shapes.total_bounds[3]], crs=ccrs.PlateCarree())

#fig, ax = plt.subplots(subplot_kw={"projection":ccrs.PlateCarree()})

# Plotting requirements
#xlim = [shapes.total_bounds[0], shapes.total_bounds[2]]
#ylim = [shapes.total_bounds[1], shapes.total_bounds[3]]
#ax.set_xlim(xlim)
#ax.set_ylim(ylim)

#fig.grid.plot(ax=ax, edgecolor="grey", color="None")
# Out:
# /opt/anaconda3/envs/pypsa-earth/lib/python3.10/site-packages/cartopy/mpl/style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %%
shapes.plot()
# Out:
# <AxesSubplot:>

# %%
countries = ["Bolivia"]
world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
shapes=world[world.name.isin(countries)].set_index("name")

fig, ax = plt.subplots(figsize=(7, 7))

#fig, ax = plt.subplots(subplot_kw={"projection":ccrs.PlateCarree()})

# Plotting requirements
xlim = [shapes.total_bounds[0], shapes.total_bounds[2]]
ylim = [shapes.total_bounds[1], shapes.total_bounds[3]]
ax.set_xlim(xlim)
ax.set_ylim(ylim)


shapes.plot(ax=ax)
# Out:
# <AxesSubplot:>
